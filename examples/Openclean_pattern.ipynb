# %% [markdown]
# ## Pattern Exercises

# %% [markdown]
# Goals:
# 1. pattern generation
# 2. basic anomaly detection
# 3. non-basic/advanced anomaly detection

# %%
import pandas as pd
import pprint

pp = pprint.PrettyPrinter(indent=4)

# %%
# load data
df = pd.read_csv('../resources/dev/urban.csv')
pp.pprint(df.shape)
df.head()
# Out:
# (31450, 17)
#    Registry Number      Business Name                        Entity Type  \
# 0        167799296   ANOVAWORKS, PLLC  FOREIGN LIMITED LIABILITY COMPANY
# 1        167799296   ANOVAWORKS, PLLC  FOREIGN LIMITED LIABILITY COMPANY
# 2        167799296   ANOVAWORKS, PLLC  FOREIGN LIMITED LIABILITY COMPANY
# 3        168957992  BLACK CROWS CORP.       FOREIGN BUSINESS CORPORATION
# 4        168957992  BLACK CROWS CORP.       FOREIGN BUSINESS CORPORATION
#
#   Registry Date         Associated Name Type First Name Middle Name Last Name  \
# 0    07/01/2020              MAILING ADDRESS        NaN         NaN       NaN
# 1    07/01/2020  PRINCIPAL PLACE OF BUSINESS        NaN         NaN       NaN
# 2    07/01/2020             REGISTERED AGENT        NaN         NaN       NaN
# 3    07/01/2020              MAILING ADDRESS        NaN         NaN       NaN
# 4    07/01/2020                    PRESIDENT       ERIC         NaN    BASCLE
#
#   Suffix Not of Record Entity  Entity of Record Reg Number  \
# 0    NaN                  NaN                          NaN
# 1    NaN                  NaN                          NaN
# 2    NaN                  NaN                   51329093.0
# 3    NaN                  NaN                          NaN
# 4    NaN                  NaN                          NaN
#
#             Entity of Record Name                  Address   \
# 0                             NaN          413 N MISSION ST
# 1                             NaN          413 N MISSION ST
# 2  NORTHWEST REGISTERED AGENT LLC           5305 RIVER RD N
# 3                             NaN  C/O PRAMEX INTERNATIONAL
# 4                             NaN  C/O PRAMEX INTERNATIONAL
#
#                   Address Continued       City State Zip Code
# 0                               NaN  WENATCHEE    WA    98801
# 1                               NaN  WENATCHEE    WA    98801
# 2                             STE B     KEIZER    OR    97303
# 3  1251 AVENUE OF THE AMERICAS, FL3   NEW YORK    NY    10020
# 4  1251 AVENUE OF THE AMERICAS, FL3   NEW YORK    NY    10020

# %% [markdown]
# ### Generate Patterns

# %%
# using the default patternfinder to quickly understand column patterns
from openclean_pattern.patternfinder import PatternFinder
column = 'Entity Type'

# %%
# create a new PatternFinder object with the data series
pf = PatternFinder(
    series = df[column]
)

# %%
# find patterns
patterns = pf.find()

# %%
pp.pprint(patterns)
# Out:
# {   5: [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA)],
#     7: [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA)],
#     9: [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA)]}

# %%
# analyze all identified patterns from the column 
for i in range(1,len(patterns)+1):
    pp.pprint("## Pattern Ranked {} for column: {}".format(i, column))
    pp.pprint(pf.top(i))
    pp.pprint(len(pf.top(i).idx))
    pp.pprint([pf.series[c] for i, c in enumerate(list(pf.top(i).idx)) if i < 10])
    print()
# Out:
# '## Pattern Ranked 1 for column: Entity Type'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA)]
# 10
# [   'foreign professional corporation',
#     'domestic limited partnership',
#     'foreign nonprofit corporation',
#     'assumed business name',
#     'domestic business trust',
#     'domestic professional corporation',
#     'domestic nonprofit corporation',
#     'foreign limited partnership',
#     'foreign business corporation',
#     'domestic business corporation']
#
# '## Pattern Ranked 2 for column: Entity Type'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA)]
# 2
# [   'domestic registered limited liability partnership',
#     'foreign registered limited liability partnership']
#
# '## Pattern Ranked 3 for column: Entity Type'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA)]
# 2
# ['domestic limited liability company', 'foreign limited liability company']

# %% [markdown]
# ### Basic Outliers

# %%
# create a new PatternFinder object with the data series
column = 'Zip Code'
pf = PatternFinder(
    series = df[column]
)
patterns = pf.find()

# %%
# looking at the patterns discovered in the zipcode column, we see there are 36 values 
# that deviate from the rest of the column 
for i in range(1,len(patterns)+1):
    pp.pprint("## Pattern Ranked {} for column: {}".format(i, column))
    pp.pprint(pf.top(i))
    pp.pprint(len(pf.top(i).idx))
    pp.pprint([pf.series[c] for i, c in enumerate(list(pf.top(i).idx)) if i < 10])
    print()
# Out:
# '## Pattern Ranked 1 for column: Zip Code'
# [PatternElement(DIGIT)]
# 1148
# [   '32256',
#     '10022',
#     '80905',
#     '33411',
#     '92865',
#     '97294',
#     '49008',
#     '77433',
#     '97282',
#     '33716']
#
# '## Pattern Ranked 2 for column: Zip Code'
# [PatternElement(ALPHANUM), PatternElement(SPACE_REP), PatternElement(ALPHANUM)]
# 9
# [   'm5e 1k3',
#     'v6z 0c8',
#     't6j 7j8',
#     'm4m 3g3',
#     'v6c 1c7',
#     'v4k 0a5',
#     'h9r 6b1',
#     'v5m 4t5',
#     'v4n 5k8']

# %%
# they are canadian zipcodes
df[df['Zip Code'].str.lower() == 'v5m 4t5']
# Out:
#        Registry Number             Business Name  \
# 16351        169564193  QUARTECH CORRECTIONS LLC
# 16352        169564193  QUARTECH CORRECTIONS LLC
# 16353        169564193  QUARTECH CORRECTIONS LLC
#
#                              Entity Type Registry Date  \
# 16351  FOREIGN LIMITED LIABILITY COMPANY    07/17/2020
# 16352  FOREIGN LIMITED LIABILITY COMPANY    07/17/2020
# 16353  FOREIGN LIMITED LIABILITY COMPANY    07/17/2020
#
#               Associated Name Type First Name Middle Name Last Name Suffix  \
# 16351              MAILING ADDRESS        NaN         NaN       NaN    NaN
# 16352                       MEMBER      DAVID         NaN  MARSHALL    NaN
# 16353  PRINCIPAL PLACE OF BUSINESS        NaN         NaN       NaN    NaN
#
#       Not of Record Entity  Entity of Record Reg Number Entity of Record Name  \
# 16351                  NaN                          NaN                   NaN
# 16352                  NaN                          NaN                   NaN
# 16353                  NaN                          NaN                   NaN
#
#                  Address  Address Continued       City             State  \
# 16351  2889 12TH AVENUE E         SUITE 650  VANCOUVER  BRITISH COLUMBIA
# 16352  2889 12TH AVENUE E         SUITE 650  VANCOUVER  BRITISH COLUMBIA
# 16353  2889 12TH AVENUE E         SUITE 650  VANCOUVER  BRITISH COLUMBIA
#
#       Zip Code
# 16351  V5M 4T5
# 16352  V5M 4T5
# 16353  V5M 4T5

# %% [markdown]
# ### Non-Basic Outliers

# %%
# Businesses

# %%
from openclean_pattern.tokenize.regex import RegexTokenizer
from openclean_pattern.datatypes.resolver import BusinessEntityResolver, DefaultTypeResolver

# create a new DefaultTypeResolver object (identifies basic types)
# intercepted by a BusinessEntityResolver (identifies company suffixes)
dtr = DefaultTypeResolver(interceptors=BusinessEntityResolver())

# create a new RegexTokenizer that'll tokenize the remaining values not identified by the type resolvers
# on all delimiters except dots(.) because they're abbreviation characters
rt = RegexTokenizer(type_resolver=dtr, abbreviations=True)

# create a new PatternFinder object with the data series and the TypeResolvers to use as part of the Tokenizer
column = 'Business Name'
pf = PatternFinder(
    series = df[column],
    tokenizer = rt
)

# %%
patterns = pf.find()

# %%
#  Ranked # 3 and 7 dont have any business suffixes
# these businesses dont have a suffix in their names, these could be potential errors
for i in range(1, len(patterns)+1):
    pp.pprint("## Pattern Ranked {} for column: {}".format(i, column))
    pp.pprint(pf.top(i))
    pp.pprint(pf.top(i).freq)
    print()
# Out:
# '## Pattern Ranked 1 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(BE)]
# 1174
#
# '## Pattern Ranked 2 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(BE)]
# 904
#
# '## Pattern Ranked 3 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA)]
# 641
#
# '## Pattern Ranked 4 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(BE)]
# 469
#
# '## Pattern Ranked 5 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(BE)]
# 394
#
# '## Pattern Ranked 6 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(BE)]
# 256
#
# '## Pattern Ranked 7 for column: Business Name'
# [PatternElement(ALPHA)]
# 168
#
# '## Pattern Ranked 8 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(BE)]
# 132
#
# '## Pattern Ranked 9 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(BE)]
# 111
#
# '## Pattern Ranked 10 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(BE)]
# 69
#
# '## Pattern Ranked 11 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(BE)]
# 23
#
# '## Pattern Ranked 12 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(BE)]
# 14
#
# '## Pattern Ranked 13 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(BE), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(BE)]
# 5
#
# '## Pattern Ranked 14 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(BE), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(BE), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA)]
# 3
#
# '## Pattern Ranked 15 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(BE), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(BE)]
# 2
#
# '## Pattern Ranked 16 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(BE)]
# 1
#
# '## Pattern Ranked 17 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(BE)]
# 1
#
# '## Pattern Ranked 18 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(PUNCTUATION), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(BE)]
# 1
#
# '## Pattern Ranked 19 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(PUNCTUATION), PatternElement(DIGIT)]
# 1
#
# '## Pattern Ranked 20 for column: Business Name'
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(BE), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(BE)]
# 1

# %%
#  Address

# %%
from openclean_pattern.datatypes.resolver import AddressDesignatorResolver, GeoSpatialResolver

# %%
# create a new DefaultTypeResolver object (identifies basic types)
# intercepted by an Address and Geospatial Resolver (identify addresses and countries)
dtr = DefaultTypeResolver(interceptors=[AddressDesignatorResolver()])

# create a new RegexTokenizer that'll tokenize the remaining values not identified by the type resolvers
# on all delimiters
rt = RegexTokenizer(type_resolver=dtr)

# create a new PatternFinder object with the data series and the TypeResolvers to use as part of the Tokenizer
column = 'Address '
pf = PatternFinder(
    series = df[column],
    tokenizer = rt
)

# %%
patterns = pf.find()

# %%
# address patterns ranked 10+ seem like possible outliers
for i in range(1, len(patterns)+1):
    pp.pprint("## Pattern Ranked {} for column: {}".format(i, column))
    pp.pprint(pf.top(i))
    pp.pprint(pf.top(i).freq)
    print()
# Out:
# '## Pattern Ranked 1 for column: Address '
# [PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(STREET)]
# 2551
#
# '## Pattern Ranked 2 for column: Address '
# [PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(STREET)]
# 1715
#
# '## Pattern Ranked 3 for column: Address '
# [PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(STREET), PatternElement(SPACE_REP), PatternElement(SUD), PatternElement(SPACE_REP), PatternElement(DIGIT)]
# 387
#
# '## Pattern Ranked 4 for column: Address '
# [PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(STREET), PatternElement(SPACE_REP), PatternElement(SUD), PatternElement(SPACE_REP), PatternElement(DIGIT)]
# 191
#
# '## Pattern Ranked 5 for column: Address '
# [PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(STREET), PatternElement(SPACE_REP), PatternElement(PUNCTUATION), PatternElement(DIGIT)]
# 63
#
# '## Pattern Ranked 6 for column: Address '
# [PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA)]
# 36
#
# '## Pattern Ranked 7 for column: Address '
# [PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(STREET), PatternElement(SPACE_REP), PatternElement(PUNCTUATION), PatternElement(DIGIT)]
# 30
#
# '## Pattern Ranked 8 for column: Address '
# [PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(STREET), PatternElement(SPACE_REP), PatternElement(STREET), PatternElement(SPACE_REP), PatternElement(SUD), PatternElement(SPACE_REP), PatternElement(DIGIT)]
# 22
#
# '## Pattern Ranked 9 for column: Address '
# [PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(STREET), PatternElement(SPACE_REP), PatternElement(STREET), PatternElement(SPACE_REP), PatternElement(PUNCTUATION), PatternElement(DIGIT)]
# 12
#
# '## Pattern Ranked 10 for column: Address '
# [PatternElement(DIGIT)]
# 5
#
# '## Pattern Ranked 11 for column: Address '
# [PatternElement(PUNCTUATION), PatternElement(DIGIT)]
# 4
#
# '## Pattern Ranked 12 for column: Address '
# [PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(STREET), PatternElement(SPACE_REP), PatternElement(SUD), PatternElement(SPACE_REP), PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(DIGIT)]
# 2
#
# '## Pattern Ranked 13 for column: Address '
# [PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(STREET)]
# 1
#
# '## Pattern Ranked 14 for column: Address '
# [PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(SUD), PatternElement(SPACE_REP), PatternElement(STREET)]
# 1
#
# '## Pattern Ranked 15 for column: Address '
# [PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(PUNCTUATION), PatternElement(DIGIT)]
# 1
#
# '## Pattern Ranked 16 for column: Address '
# [PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(STREET), PatternElement(SPACE_REP), PatternElement(SUD), PatternElement(SPACE_REP), PatternElement(DIGIT)]
# 1

# %%
for i in range(10,16):
    pp.pprint(df.loc[pf.top(i).idx, column].unique())
# Out:
# array(['42340 NW DEPOT ST', '61775 HARMONY LN', '2037 FREMONT ST',
#        '250 PRINCETON AVE STE 104', '26331 S HARMS RD'], dtype=object)
# array(['5305 RIVER RD N STE B', '3223 N CRATER LANE',
#        '12270 SW GINGHAM LANE', '1120 112TH AVE NE'], dtype=object)
# array(['5115 SE 111TH AVE', '12265 SW HALL BLVD #7'], dtype=object)
# array(['75 SE YAMHILL ST SUITE 202'], dtype=object)
# array(['4605 NE FREMONT ST'], dtype=object)
# array(['165 S MARBLE DRIVE'], dtype=object)

# %%
# Geospatial (without using the PatternFinder class)

# %%
# Combined Geo
geo = df[['Address ', 'Address Continued' ,'City' ,'State', 'Zip Code']]
geo.loc[:, 'Full Address'] = df['Address '] + ',\n' + df['Address Continued'].fillna('') + '\n' + df['City'] + ', '+df['State']+', '  + df['Zip Code']
pp.pprint(geo['Full Address'].iloc[0])
# Out:
# '413 N MISSION ST,\n\nWENATCHEE, WA, 98801'
# /home/maqzi/PycharmProjects/openclean-pattern/venv/lib/python3.7/site-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/maqzi/PycharmProjects/openclean-pattern/venv/lib/python3.7/site-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
# create a new DefaultTypeResolver object (identifies basic types)
# intercepted by an Address and Geospatial Resolver (identify addresses and countries)
dtr = DefaultTypeResolver(interceptors=[AddressDesignatorResolver(), GeoSpatialResolver()])

# create a new RegexTokenizer that'll tokenize the remaining values not identified by the type resolvers
# on all delimiters
rt = RegexTokenizer(type_resolver=dtr)

# encode unique values using the TypeResolvers in the Tokenizer
series = geo['Full Address'].unique().tolist()
encoded = rt.encode(series)

# %%
pp.pprint(encoded[0:5])
# Out:
# [   (   _'NUMERIC'_(3,'413'),
#         _'\\S'_(1,' '),
#         _'ALPHA'_(1,'n'),
#         _'\\S'_(1,' '),
#         _'STREET'_(7,'mission'),
#         _'\\S'_(1,' '),
#         _'STREET'_(2,'st'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,'\n'),
#         _'\\S'_(1,'\n'),
#         _'ALPHA'_(9,'wenatchee'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,' '),
#         _'ADMIN_2'_(2,'wa'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,' '),
#         _'NUMERIC'_(5,'98801')),
#     (   _'NUMERIC'_(4,'5305'),
#         _'\\S'_(1,' '),
#         _'STREET'_(5,'river'),
#         _'\\S'_(1,' '),
#         _'STREET'_(2,'rd'),
#         _'\\S'_(1,' '),
#         _'ALPHA'_(1,'n'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,'\n'),
#         _'SUD'_(3,'ste'),
#         _'\\S'_(1,' '),
#         _'ALPHA'_(1,'b'),
#         _'\\S'_(1,'\n'),
#         _'ALPHA'_(6,'keizer'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,' '),
#         _'ALPHA'_(2,'or'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,' '),
#         _'NUMERIC'_(5,'97303')),
#     (   _'ALPHA'_(1,'c'),
#         _'PUNC'_(1,'/'),
#         _'ALPHA'_(1,'o'),
#         _'\\S'_(1,' '),
#         _'ALPHA'_(6,'pramex'),
#         _'\\S'_(1,' '),
#         _'ALPHA'_(13,'international'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,'\n'),
#         _'NUMERIC'_(4,'1251'),
#         _'\\S'_(1,' '),
#         _'STREET'_(6,'avenue'),
#         _'\\S'_(1,' '),
#         _'ALPHA'_(2,'of'),
#         _'\\S'_(1,' '),
#         _'ALPHA'_(3,'the'),
#         _'\\S'_(1,' '),
#         _'ALPHA'_(8,'americas'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,' '),
#         _'ALPHANUM'_(3,'fl3'),
#         _'\\S'_(1,'\n'),
#         _'ADMIN_1'_(8,'new york'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,' '),
#         _'ADMIN_3'_(2,'ny'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,' '),
#         _'NUMERIC'_(5,'10020')),
#     (   _'NUMERIC'_(4,'1127'),
#         _'\\S'_(1,' '),
#         _'ADMIN_4'_(8,'broadway'),
#         _'\\S'_(1,' '),
#         _'STREET'_(6,'street'),
#         _'\\S'_(1,' '),
#         _'ADMIN_3'_(2,'ne'),
#         _'\\S'_(1,' '),
#         _'SUD'_(5,'suite'),
#         _'\\S'_(1,' '),
#         _'NUMERIC'_(3,'310'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,'\n'),
#         _'\\S'_(1,'\n'),
#         _'ADMIN_2'_(5,'salem'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,' '),
#         _'ALPHA'_(2,'or'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,' '),
#         _'NUMERIC'_(5,'97301')),
#     (   _'NUMERIC'_(4,'1373'),
#         _'\\S'_(1,' '),
#         _'ALPHA'_(2,'sw'),
#         _'\\S'_(1,' '),
#         _'ADMIN_2'_(4,'hume'),
#         _'\\S'_(1,' '),
#         _'STREET'_(2,'ct'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,'\n'),
#         _'\\S'_(1,'\n'),
#         _'ADMIN_1'_(8,'portland'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,' '),
#         _'ALPHA'_(2,'or'),
#         _'PUNC'_(1,','),
#         _'\\S'_(1,' '),
#         _'NUMERIC'_(5,'97219'))]

# %%
# align the column
from openclean_pattern.align.group import GroupAligner

ga = GroupAligner()
aligned = ga.align(encoded)

# %%
# compile the pattern
from openclean_pattern.regex.compiler import DefaultRegexCompiler

rws = DefaultRegexCompiler()
compiled = rws.compile(encoded, aligned)

# %%
# and the anomalies
anomalies = rws.anomalies(encoded, aligned)

# %%
# lets look at a pattern and it's anomaly
compiled[20]
# Out:
# [PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(SPACE_REP), PatternElement(STREET), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(SUD), PatternElement(SPACE_REP), PatternElement(DIGIT), PatternElement(SPACE_REP), PatternElement(ADMIN_LEVEL_1), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(ALPHA), PatternElement(PUNCTUATION), PatternElement(SPACE_REP), PatternElement(DIGIT)]

# %%
[series[i] for i in anomalies[20]]
# e.g. the pattern for #1 is actually:
# '5305 RIVER RD N,\nSTE B\nKEIZER, OR, 97303'
# DIGIT \S ALPHA \S STREET \s ALPHA ...
# Out:
# ['5305 RIVER RD N,\nSTE B\nKEIZER, OR, 97303',
#  '5305 RIVER RD N,\nSUITE B\nKEIZER, OR, 97303',
#  '5305 RIVER ROAD N,\nSTE B\nKEIZER, OR, 97303',
#  '740 NE 3RD STREET,\nSUITE 3\nBEND, OR, 97702',
#  '1244 NE 2ND ST,\nUNIT 1\nBEND, OR, 97701',
#  '1302 NE 3RD ST,\nSTE 1\nBEND, OR, 97701',
#  '8191 N LOMBARD ST,\nUNIT 107\nPORTLAND, OR, 97203',
#  '4150 N WILLIAMS AVE,\nAPT 418\nPORTLAND, OR, 97217',
#  '4150 N WILLIAMS AVE,\nAPT 312\nPORTLAND, OR, 97217',
#  '4357 N WILLIAMS AVE,\nAPT 312\nPORTLAND, OR, 97217',
#  '2121 SE BELMONT ST,\nAPT 125\nPORTLAND, OR, 97214',
#  '3600 N WILLIAMS AVENUE,\nAPT 216\nPORTLAND, OR, 97227',
#  '1926 W BURNSIDE ST,\nUNIT 317\nPORTLAND, OR, 97209',
#  '15597 NW ATHENS DRIVE,\nAPT 243\nPORTLAND, OR, 97229',
#  '18625 EAST BURNSIDE STREET,\nUNIT 21\nPORTLAND, OR, 97233',
#  '1259 DEBRICK RD,\n1259 DEBRICK RD\nEUGENE, OR, 97401',
#  '2501 CAPITAL AVE,\n2501 CAPITAL AVE\nMEDFORD, OR, 97504',
#  '1120 112TH AVE NE,\nSUITE 600\nBELLEVUE, WA, 98004',
#  '1909 NE SHEPARD RD,\nSUITE E\nBEND, OR, 97701',
#  '955 NW OGDEN AVE #3,\n\nBEND, OR, 97703',
#  '3762 AMBER ST NE,\nAPT 108\nSALEM, OR, 97301',
#  '827 CENTURY DR NE,\nAPT 303\nALBANY, OR, 97322',
#  '2550 CORAL AVE NE,\nAPT 108\nSALEM, OR, 97305',
#  '15 NE 57TH AVE #4,\n\nPORTLAND, OR, 97213',
#  '1500 NE 15TH AVE #331,\n\nPORTLAND, OR, 97232',
#  '3519 NE 15TH AVE #245,\n\nPORTLAND, OR, 97212',
#  '800 SOUTH DOUGLAS ROAD,\nSUITE 790\nMIAMI, FL, 33134',
#  '4949 MEADOWS ROAD #600,\n\nLAKE OSWEGO, OR, 97035',
#  '5885 MEADOWS ROAD #200,\n\nLAKE OSWEGO, OR, 97035',
#  '1132 SW 19TH AVENUE,\nSUITE 304\nPORTLAND, OR, 97205',
#  '425 NW 10TH AVE,\nSUITE 201\nPORTLAND, OR, 97209',
#  '900 SW 5TH AVENUE,\nSUITE 2500\nPORTLAND, OR, 97204',
#  '6600 SW 92ND AVE,\nSTE 200\nPORTLAND, OR, 97223',
#  '1250 NW 9TH AVE,\nSUITE 100\nPORTLAND, OR, 97209',
#  '821 NW 11TH AVE,\nAPT 505\nPORTLAND, OR, 97209',
#  '1222 NW 18TH AVE,\nAPT 502\nPORTLAND, OR, 97209',
#  '1125 NW 12TH AVE,\nAPT 202\nPORTLAND, OR, 97209',
#  '1306 SE 36TH AVE,\nAPT 11\nPORTLAND, OR, 97214',
#  '3602 SE 28TH PL,\nAPT 9\nPORTLAND, OR, 97202',
#  '529 SW 3RD AVE,\nSUITE 120\nPORTLAND, OR, 97204',
#  '1818 SW 4TH AVE,\nAPT 1202\nPORTLAND, OR, 97201',
#  '125 SE 151ST AVE,\nAPT 201\nPORTLAND, OR, 97233',
#  '12909 SW 68TH PARKWAY,\nSTE 290\nPORTLAND, OR, 97223',
#  '1834 SW 58TH AVENUE,\nSUITE 200\nPORTLAND, OR, 97221',
#  '1843 SW 16TH AVE,\nAPT 3\nPORTLAND, OR, 97201',
#  '333 NW 9TH AVE,\nUNIT 1310\nPORTLAND, OR, 97209',
#  '111 SW 5TH AVENUE,\nSUITE 3800\nPORTLAND, OR, 97204',
#  '4312 SE 27TH AVENUE,\nUNIT 2\nPORTLAND, OR, 97202',
#  '52 SE 146TH AVE,\nAPT 910\nPORTLAND, OR, 97233',
#  '1515 NW 21ST AVE,\nUNIT 516\nPORTLAND, OR, 97209',
#  '1277 TREAT BOULEVARD,\nSUITE 400\nWALNUT CREEK, CA, 94597',
#  '2241 GREENSPRINGS DRIVE,\nUNIT 66\nKLAMATH FALLS, OR, 97601',
#  '23241 GREENSPRINGS DRIVE,\nUNIT 66\nKLAMATH FALLS, OR, 97601',
#  '707 SW WASHINGTON ST,\nSTE 1500\nPORTLAND, OR, 97205',
#  '2233 NW FLANDERS STREET,\nAPT 12\nPORTLAND, OR, 97210',
#  '107 SE WASHINGTON ST,\nSUITE 156\nPORTLAND, OR, 97214',
#  '707 SW WASHINGTON STREET,\nSUITE 1100\nPORTLAND, OR, 97205',
#  '0224 SW HAMILTON STREET,\nSUITE 301\nPORTLAND, OR, 97239',
#  '319 SW WASHINGTON ST,\nSTE 301\nPORTLAND, OR, 97204',
#  '2380 SW VERMONT ST,\nAPT 10\nPORTLAND, OR, 97219',
#  '2266 MCGILCHRIST ST SE,\nSTE 200\nSALEM, OR, 97302',
#  '2120 ROBINS LN SE,\nUNIT 63\nSALEM, OR, 97306',
#  '780 COMMERCIAL ST SE,\nSUITE 100\nSALEM, OR, 97301',
#  '780 COMMERCIAL ST SE,\nSTE 100\nSALEM, OR, 97301',
#  '250 CHURCH ST SE,\nSTE 202\nSALEM, OR, 97301',
#  '1703 WALN DR SE,\nAPT 141\nSALEM, OR, 97306',
#  '780 COMMERCIAL STREET SOUTHEAST,\nSUITE 100\nSALEM, OR, 97301',
#  '780 COMMERCIAL STREET SE,\nSTE 100\nSALEM, OR, 97301',
#  '780 COMMERCIAL STREET SE,\nSUITE 100\nSALEM, OR, 97301',
#  '1015 NE 89TH AVE,\nAPT 101\nHILLSBORO, OR, 97006',
#  '1280 NE 63RD WAY,\nUNIT 801\nHILLSBORO, OR, 97124',
#  '508 WEST 5TH STREET,\nSUITE 250\nCHARLOTTE, NC, 28202',
#  '1097 NE 11TH ST,\nUNIT 105\nREDMOND, OR, 97756',
#  '528 WEST 10TH AVENUE,\nAPT 1\nEUGENE, OR, 97401',
#  '1015 NE 89TH AVE,\nAPT 101\nBEAVERTON, OR, 97006',
#  '5305 RIVER RD NORTH,\nSTE B\nASHLAND, OR, 97520',
#  '5305 RIVER ROAD NORTH,\nSUITE B\nKEIZER, OR, 97303',
#  '5305 RIVER RD NORTH,\nSTE E\nKEIZER, OR, 97303',
#  '5305 RIVER RD NORTH,\nSUITE B\nKEIZER, OR, 97303',
#  '5305 RIVER RD NORTH,\nSTE B\nKEIZER, OR, 97303',
#  '3616 FAR WEST,\nSUITE 117-294\nAUSTIN, TX, 78731',
#  '8300 NE QUATAMA STREET,\nUNIT 11\nBEAVERTON, OR, 97006',
#  '330 NE LINCOLN ST,\nSUITE 200\nHILLSBORO, OR, 97124',
#  '1 CHASE CORPORATE DR,\nSUITE 400\nHOOVER, AL, 35244',
#  '1915 NE STUCKI AVENUE,\nSUITE 308\nHILLSBORO, OR, 97006',
#  '1200 NE TERRITORIAL RD,\nUNIT 34\nCANBY, OR, 97013',
#  '80 E RICH ST,\nSUITE 120\nCOLUMBUS, OH, 43215',
#  '14708 SW BEARD RD,\nAPT 225\nBEAVERTON, OR, 97007',
#  '8171 MAPLE LAWN BLVD,\nSUITE 375\nFULTON, MD, 20759',
#  '4601 SOUTH PACIFIC HWY,\nUNIT 55\nPHOENIX, OR, 97535',
#  '400 E ROYAL LN,\nSTE 290\nIRVING, TX, 75039',
#  '12725 SW MILLIKAN WAY,\nSUITE 300\nBEAVERTON, OR, 97005',
#  '12725 SW MILLIKAN WAY,\nSTE 300\nBEAVERTON, OR, 97005',
#  '260 SW MADISON AVE,\nSUITE 106\nCORVALLIS, OR, 97333',
#  '256 E HURLBURT AVE,\nSUITE 109\nHERMISTON, OR, 97838',
#  '15395 SW MALLARD DR,\nSTE 104\nBEAVERTON, OR, 97007',
#  '7143 SW SAGERT STREET,\nUNIT 104\nTUALATIN, OR, 97062',
#  '1651 SE LAVA DR,\nAPT 89\nMILWAUKIE, OR, 97222',
#  '11529 SW ZURICH STREET,\nUNIT 205\nWILSONVILLE, OR, 97070',
#  '19730 SW CIPOLE RD,\nBLDG 1\nTUALATIN, OR, 97062',
#  '3600 SW METOLIUS AVE,\nUNIT 354\nREDMOND, OR, 97756',
#  '1340 SOUTH SPECTRUM BLVD,\nSTE 200\nSCOTTSDALE, AZ, 85256',
#  '7885 SW VLAHOS DR,\nAPT 106\nWILSONVILLE, OR, 97070',
#  '1747 E MORTEN AVE,\nSUITE 202\nPHOENIX, AZ, 85020',
#  '260 SW MADISON AVE,\nSUITE 120\nCORVALLIS, OR, 97333',
#  '17650 NW CORNELL RD,\nAPT 15\nBEAVERTON, OR, 97006',
#  '20 S THIRD STREET,\nSUITE 210\nCOLUMBUS, OH, 43215',
#  '7110 SW HAZELFERN RD,\nSTE 260\nTIGARD, OR, 97224',
#  '6909 SW WILSONVILLE RD,\nAPT 205\nWILSONVILLE, OR, 97070',
#  '14631 SW MILLIKAN WAY,\nSUITE 4\nBEAVERTON, OR, 97003',
#  '2141 E CEDAR STREET,\nSUITE 6\nTEMPE, AZ, 85281',
#  '2123 NW ALOCLEK DRIVE,\nSUITE 1205\nHILLSBORO, OR, 97124',
#  '2123 NW ALOCLEK DRIVE,\nSUITE 1203\nHILLSBORO, OR, 97124',
#  '255 E BARNETT ROAD,\nSTE 110\nMEDFORD, OR, 97501',
#  '320 E BUFFALO STREET,\nSUITE 500\nMILWAUKEE, WI, 53202',
#  '15272 SW MILLIKAN WAY,\nAPT 424\nBEAVERTON, OR, 97003',
#  '220 W RAPP ROAD,\nUNIT 5\nTALENT, OR, 97540',
#  '4925 SW JAMIESON RD,\nAPT 38\nBEAVERTON, OR, 97005',
#  '4925 SW JAMIESON AVE,\nAPT 38\nBEAVERTON, OR, 97005',
#  '14320 VENTURA BLVD #616,\n\nSHERMAN OAKS, CA, 91423',
#  '1430 VENTURA BLVD #616,\n\nSHERMAN OAKS, CA, 91423',
#  '24050 SE STARK STREET,\nAPT 905\nGRESHAM, OR, 97030',
#  '2206 NW BIRDSDALE AVE,\nSUITE 1\nGRESHAM, OR, 97030',
#  '2951 NW DIVISION ST,\nSTE 110\nGRESHAM, OR, 97030',
#  '2951 NW DIVISION STREET,\nSUITE 110\nGRESHAM, OR, 97030',
#  '2951 NW DIVISION STREET,\nSTE 110\nGRESHAM, OR, 97030',
#  '235 FRONT ST SE,\nSTE 400\nSALEM, OR, 97301',
#  '165 S. MARBLE DRIVE,\n\nGRANTS PASS, OR, 97526',
#  '4940 S LANDING DRIVE #123,\n\nPORTLAND, OR, 97239',
#  '815 SW VISTA AVE,\nAPT 203\nPORTLAND, OR, 97205',
#  '3601 SW RIVER PARKWAY,\nUNIT 1808\nPORTLAND, OR, 97239',
#  '5250 S LANDING DR,\nUNIT 306\nPORTLAND, OR, 97239',
#  '5250 S LANDING DRIVE,\nUNIT 306\nPORTLAND, OR, 97239',
#  '4949 SW LANDING DR,\nUNIT 721\nPORTLAND, OR, 97239',
#  '4920 S LANDING DRIVE,\nAPT 305\nPORTLAND, OR, 97239',
#  '742 SW VISTA AVE,\nAPT 42\nPORTLAND, OR, 97205',
#  '832 SW VISTA AVENUE,\nAPT 4\nPORTLAND, OR, 97205',
#  '620 SW PARK AVE,\nAPT 64\nPORTLAND, OR, 97205',
#  '303 BRADLEY DRIVE SOUTHEAST #14,\n\nSALEM, OR, 97302',
#  '3850 SE 82ND AVE,\nBOX 90355\nPORTLAND, OR, 97290',
#  'PRAIRIE GROVE,\n104 ANGUS DR\nPRAIRIE GROVE, AR, 72753',
#  '4287 SE INTERNATIONAL WAY,\nSUITE C\nMILWAUKIE, OR, 97222',
#  '18290 NW CORNELL RD,\nAPT H\nBEAVERTON, OR, 97006',
#  '12270 SW GINGHAM LANE,\nUNIT D\nBEAVERTON, OR, 97008',
#  '14200 SOUTHEAST MCLOUGHLIN BOULEVARD,\nSUITE K\nMILWAUKIE, OR, 97267',
#  '8700 SW CREEKSIDE PLACE,\nSUITE A\nBEAVERTON, OR, 97008',
#  'NEWBERG OR,\n600 N SITKA AVE\nNEWBERG, OR, 97132',
#  '300 EXECUTIVE CENTER DRIVE,\nSUITE 201\nGREENVILLE, SC, 29615',
#  '1114 LOST CREEK BLVD,\nSUITE 500\nAUSTIN, TX, 78746',
#  '422 NW 13TH AVE #727,\n\nPORTLAND, OR, 97209',
#  '3650 SE 29TH AVE #1401,\n\nPORTLAND, OR, 97202',
#  '1221 SW 10TH AVE #1314,\n\nPORTLAND, OR, 97205',
#  '721 NW 9TH AVE #227,\n\nPORTLAND, OR, 97209',
#  '1245 SE 49TH AVE #1,\n\nPORTLAND, OR, 97215',
#  '25 NW 23RD PL #480,\n\nPORTLAND, OR, 97210',
#  '422 NW 13TH AVE #763,\n\nPORTLAND, OR, 97209',
#  '1650 NW 13TH AVE #503,\n\nPORTLAND, OR, 97209',
#  '1550 SE 20TH AVE #301,\n\nPORTLAND, OR, 97214',
#  '5708 SE 136TH AVENUE #2,\n\nPORTLAND, OR, 97236',
#  '22 SE 80TH AVE #8,\n\nPORTLAND, OR, 97215',
#  '10000 NE 7TH AVE,\nSUITE 330I\nVANCOUVER, WA, 98685',
#  '8420 N IVANHOE ST #83688,\n\nPORTLAND, OR, 97203',
#  '2056 NW GLISAN ST #5,\n\nPORTLAND, OR, 97209',
#  '1407 SE STARK STREET #5,\n\nPORTLAND, OR, 97214',
#  '3339 SE DIVISION ST #114,\n\nPORTLAND, OR, 97202',
#  '1470 NW GLISAN ST #1405,\n\nPORTLAND, OR, 97209',
#  '7327 SW BARNES RD #205,\n\nPORTLAND, OR, 97225',
#  '3439 SE HAWTHORNE BLVD #983,\n\nPORTLAND, OR, 97214',
#  '11918 SE DIVISION STREET #1004,\n\nPORTLAND, OR, 97266',
#  '3439 SE HAWTHORNE BLVD #1055,\n\nPORTLAND, OR, 97214',
#  '515 SW SALTZMAN RD #880,\n\nPORTLAND, OR, 97229',
#  '3439 SE HAWTHORNE BLVD #206,\n\nPORTLAND, OR, 97214',
#  '7327 SW BARNES RD #303,\n\nPORTLAND, OR, 97225',
#  '3439 SE HAWTHORNE BLVD #1046,\n\nPORTLAND, OR, 97214',
#  '10 S PORTER STREET #307,\n\nPORTLAND, OR, 97201',
#  '10940 SW BARNES RD #367,\n\nPORTLAND, OR, 97225',
#  '3055 NW YEON AVE #6046,\n\nPORTLAND, OR, 97210',
#  '630 SE YAMHILL ST #114,\n\nPORTLAND, OR, 97214',
#  '3720 SW BOND AVE #1010,\n\nPORTLAND, OR, 97239',
#  '101 SW MADISON ST #1472,\n\nPORTLAND, OR, 97207',
#  '2949 SE YAMHILL ST #15,\n\nPORTLAND, OR, 97214',
#  '7583 SW ALOMA WAY #2,\n\nPORTLAND, OR, 97223',
#  '1455 NW IRVING ST #200,\n\nPORTLAND, OR, 97209',
#  '2081 NW EVERETT ST #202,\n\nPORTLAND, OR, 97209',
#  '10940 SW BARNES ROAD #374,\n\nPORTLAND, OR, 97225',
#  '3439 SE HAWTHORNE BLVD #1032,\n\nPORTLAND, OR, 97214',
#  '16388 THIRD STREET #407,\n\nLA PINE, OR, 97739',
#  '29811 TURNER ST #1283,\n\nGOLD BEACH, OR, 97444',
#  '2945 NW CHARDONNAY LANE,\nUNIT 2\nBEND, OR, 97703',
#  '335 SE ROOSEVELT AVE,\nLOT 4\nBEND, OR, 97702',
#  '2945 NW CHARDONNAY STREET,\nUNIT 2\nBEND, OR, 97703',
#  '1197 CENTURY DR NE #36,\n\nALBANY, OR, 97322',
#  '3762 AMBER ST NE #108,\n\nSALEM, OR, 97301',
#  '4130 SUNNYVIEW RD NE #75,\n\nSALEM, OR, 97305',
#  '128 BAYVIEW WAY NE #101,\n\nSALEM, OR, 97301',
#  '600 NW NAITO PARKWAY,\nSTE G\nPORTLAND, OR, 97209',
#  '18423 NW CHEMEKETA LN,\nUNIT B\nPORTLAND, OR, 97229',
#  '8155 SW INTERMARK ST,\nAPT J\nPORTLAND, OR, 97225',
#  '1837 SE ANKENY ST,\nAPT B\nPORTLAND, OR, 97214',
#  '8700 SW BARBUR COURT,\nSUITE S\nPORTLAND, OR, 97219',
#  '5130 SW MULTNOMAH BLVD,\nAPT E\nPORTLAND, OR, 97219',
#  '7548 SW BARNES ROAD,\nUNIT E\nPORTLAND, OR, 97225',
#  '18495 NW CHEMEKETA LN,\nAPT D\nPORTLAND, OR, 97229',
#  '6510 SE FOSTER ROAD,\nSUITE D\nPORTLAND, OR, 97206',
#  '698 12TH ST SE,\nSUITE 200\nSALEM, OR, 97301',
#  '698 12TH ST SE,\nSTE 201\nSALEM, OR, 97301',
#  '698 12TH ST SE,\nSTE 200\nSALEM, OR, 97301',
#  '2200 RITTENHOUSE ST,\nSTE 175\nDES MOINES, IA, 50321',
#  '4651 CHARLOTTE PARK DR,\nSTE 300\nCHARLOTTE, NC, 28217',
#  '1120 BAILEY HILL RD,\nSTE 15\nEUGENE, OR, 97402',
#  '15991 RED HILL AVE,\nSTE 100\nTUSTIN, CA, 92780',
#  '12600 SW CRESCENT STREET,\nUNIT 424\nBEAVERTON, OR, 97005',
#  '820 CRATER LAKE AVE,\nSUITE 106\nMEDFORD, OR, 97504',
#  '4800 SW MEADOWS ROAD,\nSUITE 300\nBEAVERTON, OR, 97005',
#  '5305 RIVER ROAD N,\nSUITE B1\nKEIZER, OR, 97303',
#  '5305 RIVER RD N,\nSTE B1\nKEIZER, OR, 97303',
#  '5305 RIVER ROAD N,\nSTE B1\nKEIZER, OR, 97303',
#  '543 NW YORK DR #160,\n\nBEND, OR, 97703',
#  '6827 SW 26TH AVE,\nUNIT C\nPORTLAND, OR, 97219',
#  '1308 SE 36TH AVE,\nAPT C\nPORTLAND, OR, 97214',
#  '5119 SE 41ST AVE,\nSUITE A\nPORTLAND, OR, 97202',
#  '8333 SE 23RD AVE,\nUNIT C\nPORTLAND, OR, 97202',
#  '2208 SE 43RD AVE,\nUNIT B\nPORTLAND, OR, 97215',
#  '2548 SE 141ST AVE,\nUNIT A\nPORTLAND, OR, 97236',
#  '176 MARKET AVE,\nAPT 3\nCOOS BAY, OR, 97420',
#  '63722 ELLEN STREET,\nAPT 1\nCOOS BAY, OR, 97420',
#  'UPPER MARLBORO,\n1612 YUHAS COURT\nUPPER MARLBORO, MD, 20774',
#  '304 S JONES BLVD,\nSTE 2719\nLAS VEGAS, NV, 89107',
#  '2190 W BURNSIDE ST,\nSUITE A\nPORTLAND, OR, 97210',
#  '3122 N WILLIAMS AVE,\nAPT B\nPORTLAND, OR, 97227',
#  '207 SW 1ST AVE #106,\n\nCANBY, OR, 97013',
#  '16446 SE 135TH AVE #49,\n\nCLACKAMAS, OR, 97015',
#  '4200 SW 107TH AVE #104,\n\nBEAVERTON, OR, 97005',
#  '1865 NW 169TH PL #201,\n\nBEAVERTON, OR, 97006',
#  '111 E 1ST ST #1407,\n\nPHOENIX, OR, 97535',
#  '1800 BLANKENSHIP ROAD,\nSUITE 200\nWEST LINN, OR, 97068',
#  '1800 BLANKENSHIP ROAD,\nSTE 160\nWEST LINN, OR, 97068',
#  '3595 CEDAROAK DR,\nAPT 29\nWEST LINN, OR, 97068',
#  '5665 HOOD ST,\nUNIT 512\nWEST LINN, OR, 97068',
#  '22 NE 2ND AVE,\nAPT 2210\nPORTLAND, OR, 97232',
#  '1927 NE 66TH AVE,\nAPT 175\nPORTLAND, OR, 97213',
#  '4201 NE 125TH PLACE,\nAPT 173\nPORTLAND, OR, 97230',
#  '401 NE 19TH AVE,\nSUITE 200\nPORTLAND, OR, 97232',
#  '2025 NE 42ND AVE,\nAPT 205\nPORTLAND, OR, 97213',
#  '827 NE 99TH AVE,\nAPT 32\nPORTLAND, OR, 97220',
#  '3519 NE 15TH AVE,\nSTE 424\nPORTLAND, OR, 97212',
#  '1061 NE 9TH AVE,\nAPT 1329\nPORTLAND, OR, 97232',
#  '1580 NE 32ND AVENUE,\nAPARTMENT 415\nPORTLAND, OR, 97232',
#  '5734 NE 27TH AVE,\nAPT 4\nPORTLAND, OR, 97211',
#  '12428 NE HALSEY ST,\nAPT 70\nPORTLAND, OR, 97230',
#  '4417 NE KILLINGSWORTH STREET,\nUNIT 112\nPORTLAND, OR, 97218',
#  '10535 NE GLISAN STREET,\nSTE 200\nPORTLAND, OR, 97220',
#  '10535 NE GLISAN STREET,\nSUITE 200\nPORTLAND, OR, 97220',
#  '11 NE MLK BLVD,\nSUITE 301\nPORTLAND, OR, 97232',
#  '10535 NE GLISAN ST,\nSTE 200\nPORTLAND, OR, 97220',
#  '12428 NE HALSEY ST,\nAPT 55\nPORTLAND, OR, 97220',
#  '12265 SW HALL BLVD #7,\n\nTIGARD, OR, 97223',
#  '1100 NW WARRENTON DR #351,\n\nWARRENTON, OR, 97146',
#  '1515 NW FIR AVE #31,\n\nREDMOND, OR, 97756',
#  '11255 SW GREENBURG RD #30,\n\nTIGARD, OR, 97223',
#  '1022 NW BRIARCREEK WAY #622,\n\nBEAVERTON, OR, 97006',
#  '10029 SW NIMBUS AVENUE #220,\n\nBEAVERTON, OR, 97008',
#  '2400 SE STRATUS AVE #58,\n\nMCMINNVILLE, OR, 97128',
#  '18861 SW MARTINAZZI AVE #207,\n\nTUALATIN, OR, 97062',
#  '100 N GRAPE ST #306,\n\nMEDFORD, OR, 97501',
#  '30490 SW ROGUE LANE #3104,\n\nWILSONVILLE, OR, 97070',
#  '6975 SW SANDBURG STREET #190,\n\nTIGARD, OR, 97223',
#  '6340 N CAMPBELL AVENUE #240,\n\nTUCSON, AZ, 85718',
#  '7357 SW BEVELAND ST #100,\n\nTIGARD, OR, 97223',
#  '12042 SE SUNNYSIDE RD #263,\n\nCLACKAMAS, OR, 97015',
#  '2960 NW TYLER AVE #205,\n\nCORVALLIS, OR, 97330',
#  '527 W JACKSON ST #3,\n\nMONMOUTH, OR, 97361',
#  '33 N CENTRAL AVE,\nSTE 100\nMEDFORD, OR, 97501',
#  '1970 TABLE ROCK ROAD,\nAPT 4\nMEDFORD, OR, 97501',
#  '19000 NW EVERGREEN PKWY,\nAPT 275\nHILLSBORO, OR, 97124',
#  '328 S CENTRAL AVE,\nSUITE 110\nMEDFORD, OR, 97501',
#  '2839 SW WESTERN BLVD,\nAPT 103\nCORVALLIS, OR, 97333',
#  '16205 NW BETHANY COURT,\nSTE 100\nBEAVERTON, OR, 97006',
#  '4585 SW MUELLER DR,\nAPT G106\nBEAVERTON, OR, 97078',
#  '1175 E MAIN STREET,\nSUITE 1F\nMEDFORD, OR, 97504',
#  '625 NW SPRUCE ST,\nAPT C7\nHERMISTON, OR, 97838',
#  '3000 S OCEAN DR,\nAPT 206\nHOLLYWOOD, FL, 33019',
#  '738 NW COLUMBIA STREET,\nSUITE A\nBEND, OR, 97703',
#  '296 E 5TH AVE,\nSTE 124\nEUGENE, OR, 97401',
#  '363 E 17TH AVE,\nUNIT 4\nEUGENE, OR, 97401',
#  '1284 N 19TH ST,\nUNIT 98\nPHILOMATH, OR, 97370',
#  '439 W 2ND AVE,\nSUITE 2\nEUGENE, OR, 97401',
#  '10900 SW 76TH PL,\nUNIT 51\nTIGARD, OR, 97223',
#  '14010 SW 112TH AVE,\nAPT 68\nTIGARD, OR, 97224',
#  '20750 SW 115TH AVE,\nSUITE 190\nTUALATIN, OR, 97062',
#  '7228 SW 204TH AVE,\nAPT 2\nBEAVERTON, OR, 97007',
#  '7276 SW 204TH AVE,\nAPT 2\nBEAVERTON, OR, 97007',
#  '440 W 6TH ST,\nSUITE 13\nEUGENE, OR, 97401',
#  '4725 SW 139TH AVENUE,\nAPT 13\nBEAVERTON, OR, 97005',
#  '18880 SW 84TH AVE,\nUNIT 11\nTUALATIN, OR, 97062',
#  '18880 SW 84TH AVENUE,\nUNIT 11\nTUALATIN, OR, 97062',
#  '760 NW 185TH AVE,\nUNIT 206\nBEAVERTON, OR, 97006',
#  '360 E 10TH AVENUE,\nSUITE 104\nEUGENE, OR, 97401',
#  '451 S 1ST AVE,\nSTE 400\nHILLSBORO, OR, 97123',
#  '1416 SW 174TH AVE,\nAPT 203\nBEAVERTON, OR, 97003',
#  '545 NE THOMPSON ST,\nAPT 2\nPORTLAND, OR, 97212',
#  '1127 BROADWAY ST NE,\nSTE 310\nSALEM, OR, 97301',
#  '1127 BROADWAY ST NE,\nSUITE 310\nSALEM, OR, 97301',
#  '1127 BROADWAY STREET NE,\nSUITE 310\nSALEM, OR, 97301',
#  '1020 SW TAYLOR ST,\nSUITE 340\nPORTLAND, OR, 97205',
#  '6665 SW HAMPTON ST,\nSUITE 200\nPORTLAND, OR, 97223',
#  '117 SW TAYLOR ST,\nSTE 300\nPORTLAND, OR, 97204',
#  '6665 SW HAMPTON STREET,\nSUITE 200\nPORTLAND, OR, 97223',
#  '117 SW TAYLOR ST,\nSUITE 300\nPORTLAND, OR, 97204',
#  '17925 SW ROSA RD,\nAPARTMENT 16\nBEAVERTON, OR, 97078',
#  '1325 N GRAND AVE,\nSUITE 100\nCOVINA, CA, 91724',
#  '11280 NE EVERGREEN PARKWAY,\nSUITE 204\nHILLSBORO, OR, 97006',
#  '11280 NE EVERGREEN PARKWAY,\nSUITE 209\nHILLSBORO, OR, 97006',
#  '18750 WILLAMETTE DR,\nSTE F\nWEST LINN, OR, 97068',
#  'PO BOX 126,\n807 MILL ST\nCOVE, OR, 97824',
#  '1111 N ROOSEVELT DR,\nSUITE 350\nSEASIDE, OR, 97138',
#  '1000 SE 160TH AVE,\nK-87\nVANCOUVER, WA, 98683',
#  '2720 NE 205TH AVE,\nAPT 239\nFAIRVIEW, OR, 97024',
#  'K-87,\n1000 SE 160TH AVE\nVANCOUVER, WA, 98683',
#  '2034 COLUMBIA BLVD #205,\n\nSAINT HELENS, OR, 97051',
#  '2034 COLUMBIA BLVD #163,\n\nSAINT HELENS, OR, 97051',
#  '2034 COLUMBIA BLVD #236,\n\nSAINT HELENS, OR, 97051',
#  '680 STADIUM DR N,\nUNIT C\nMONMOUTH, OR, 97361',
#  '14816 SE MISTY DR,\n302\nHAPPY VALLEY, OR, 97086',
#  '106 NW F ST,\n359\nGRANTS PASS, OR, 97526',
#  '726 PACIFIC WAY,\nPO BOX 2443\nGEARHART, OR, 97138',
#  '22343 SILETZ HWY,\nPO BOX 738\nSILETZ, OR, 97380',
#  '9924 MARQUAM CIRCLE,\nPO BOX 282\nMOLALLA, OR, 97038',
#  '255 DOGWOOD ST,\nPO BOX 626\nLYONS, OR, 97358',
#  '235 SE 165TH AVE,\nAPT#225\nPORTLAND, OR, 97233',
#  '4407 N DIVISION ST,\nSUITE 910\nSPOKANE, WA, 99208',
#  '1902 2ND STREET #5,\n\nLA GRANDE, OR, 97850',
#  '1916 MADRAS ST SE,\nUNIT 2027\nSALEM, OR, 97306',
#  "841 O'HARE PARKWAY,\nSTE 100\nMEDFORD, OR, 97504",
#  '1107 NW 15TH STREET #214,\n\nGRESHAM, OR, 97030',
#  '5023 W 120TH AVE #316,\n\nBROOMFIELD, CO, 80020',
#  '204 SE STONEMILL DRIVE,\nSUITE 205\nVANCOUVER, WA, 98684',
#  '23200 NE SANDY BLVD #31,\n\nTROUTDALE, OR, 97060',
#  '114 WEST ADAMS AVENUE #1,\n\nSISTERS, OR, 97759',
#  '120 E 23RD ST,\nSUITE 4057\nNEW YORK, NY, 10010',
#  '262 W 38TH ST,\nRM 402\nNEW YORK, NY, 10018',
#  '205 BOONE RD SE #44,\n\nSALEM, OR, 97306',
#  '1284 ROYVONNE AVE SE #52,\n\nSALEM, OR, 97302',
#  '1900 HINES ST SE #200,\n\nSALEM, OR, 97302',
#  '5 CENTERPOINTE DRIVE,\nSUITE 400\nLAKE OSWEGO, OR, 97035',
#  '14523 WESTLAKE DR,\nSUITE 7\nLAKE OSWEGO, OR, 97035',
#  '412 JEFFERSON PARKWAY,\nSUITE 100\nLAKE OSWEGO, OR, 97035',
#  '8 STATE STREET,\nSUITE 105\nLAKE OSWEGO, OR, 97034',
#  '17970 SW JOHNSON ST,\nAPT C\nBEAVERTON, OR, 97003',
#  '19040 SW SHAW ST,\nUNIT C\nBEAVERTON, OR, 97078',
#  '10200 SW ALLEN BLVD,\nSUITE G\nBEAVERTON, OR, 97005',
#  '732 SOUTHWEST 3RD AVE,\nSTE 401\nPORTLAND, OR, 97204',
#  '201 WEST MAIN ST,\nSTE 4A\nMEDFORD, OR, 97501',
#  '16123 LOWER HARBOR ROAD,\nGENERAL DELIVERY\nBROOKINGS, OR, 97415',
#  '12900 SW CRESCENT ST #333,\n\nBEAVERTON, OR, 97005',
#  '1314 B CENTER DR #116,\n\nMEDFORD, OR, 97501',
#  '3000 LAVA RIDGE CT #200,\n\nROSEVILLE, CA, 95661',
#  '3235 HILLCREST PARK DRIVE #106,\n\nMEDFORD, OR, 97504',
#  '2955 N HWY 97 #201,\n\nBEND, OR, 97703',
#  '990 N 1ST ST,\nSTE A\nSILVERTON, OR, 97381',
#  '1060 CRATER LAKE AVE,\nSTE C\nMEDFORD, OR, 97504',
#  '3811 CRATER LAKE HWY,\nSUITE B\nMEDFORD, OR, 97504',
#  '5125 SW SCHOLLS FERRY RD,\n34\nPORTLAND, OR, 97225',
#  '7153 SOUTHWEST SAGERT STREET,\nUNIT 109\nTUALATIN, OR, 97062',
#  '9924 MARQUAM CIRLE,\nPO BOX 282\nMOLALLA, OR, 97038',
#  '11105 MAIN ST NE #19,\n\nDONALD, OR, 97020',
#  '1542 MEADOWLARK DRIVE #13,\n\nGREAT FALLS, MT, 59404',
#  '1994 NE ZACHARY CT,\nAPT 2\nBEND, OR, 97701',
#  '1567 NE RUMGAY LANE,\nUNIT 1\nBEND, OR, 97701',
#  '6120 SW 18 DR,\nAPT 33\nPORTLAND, OR, 97239',
#  '716 SE 34 AVENUE,\nAPT 2\nPORTLAND, OR, 97214',
#  '512 S HOBART BLVD,\nAPT 607\nLOS ANGELES, CA, 90020',
#  '5200 MEADOWS RD,\nSUITE 200\nLAKE OSWEGO, OR, 97035',
#  '4900 MEADOWS ROAD,\nSUITE 300\nLAKE OSWEGO, OR, 97035',
#  '4949 MEADOWS ROAD,\nSUITE 630\nLAKE OSWEGO, OR, 97035',
#  '5285 MEADOWS RD,\nSTE 199\nLAKE OSWEGO, OR, 97035',
#  '5285 MEADOWS RD,\nSUITE 235\nLAKE OSWEGO, OR, 97035',
#  '1600 VALLEY RIVER DR,\nSTE 220\nEUGENE, OR, 97401',
#  '1580 VALLEY RIVER DR,\nSUITE 210\nEUGENE, OR, 97401',
#  '1221 NE 51ST AVE #22,\n\nHILLSBORO, OR, 97124',
#  '3003 WEST 11TH AVE #284,\n\nEUGENE, OR, 97402',
#  '13500 SW PACIFIC HWY,\nPMB 215\nTIGARD, OR, 97223',
#  '9450 SW GEMINI DR,\nPMB 49974\nBEAVERTON, OR, 97008',
#  '9450 SW GEMINI DR,\nPMB 49971\nBEAVERTON, OR, 97008',
#  '4850 S PACIFIC HWY,\nWORKSHOP 3\nPHOENIX, OR, 97535',
#  '4850 SOUTH PACIFIC HIGHWAY,\nWORKSHOP 3\nPHOENIX, OR, 97535',
#  '4150 NE MLK BLVD #506,\n\nPORTLAND, OR, 97211',
#  '11954 NE GLISAN ST #113,\n\nPORTLAND, OR, 97220',
#  '3340 NE MLK BLVD #507,\n\nPORTLAND, OR, 97212',
#  'NUMBER 230243,\n12210 SW MAIN ST\nTIGARD, OR, 97223',
#  'POB 596,\n64501 E LOOKOUT DRIVE\nBRIGHTWOOD, OR, 97011',
#  '327 SE ROBERTS AVE #3,\n\nGRESHAM, OR, 97080',
#  '3604 SE POWELL VALLEY #324,\n\nGRESHAM, OR, 97080',
#  '8630 SW SCHOLLS FERRY RD,\n249\nBEAVERTON, OR, 97008',
#  '8176 SW APPLE WAY,\nAPT T202\nPORTLAND, OR, 97225',
#  '318 NE 23RD STREET,\nO 1103\nGRESHAM, OR, 97030',
#  '3181 NE 23RD STREET,\nO 1103\nGRESHAM, OR, 97030',
#  '3181 NE 23RD ST,\nAPT 1103\nGRESHAM, OR, 97030',
#  '2001 NE ALOCIEK DR #M216,\n\nHILLSBORO, OR, 97124',
#  '10610 NE 9TH PL,\nUNIT 2206\nBELLEVUE, WA, 98004',
#  '5900 NE 152ND AVE,\nSUITE 250\nVANCOUVER, WA, 98682',
#  '10610 NE 9TH PLACE,\nUNIT 2206\nBELLEVUE, WA, 98004',
#  '295 S WATER STREET #300,\n\nKENT, OH, 44240',
#  '7241 185TH AVE NE #2860,\n\nREDMOND, WA, 98073',
#  '1 SW COLUMBIA STREET,\nSUITE 1850\nPORTLAND, OR, 97204',
#  '1675 SW MARLOW AVENUE,\nSUITE 404\nPORTLAND, OR, 97225',
#  '111 SW COLUMBIA ST,\nSUITE 700\nPORTLAND, OR, 97201',
#  '111 SW COLUMBIA STREET,\nSUITE 700\nPORTLAND, OR, 97201',
#  '1 SW COLUMBIA STREET,\nSUITE 458\nPORTLAND, OR, 97204',
#  '1 SW COLUMBIA STREET,\nSUITE 458\nPORTLAND, OR, 97258',
#  '1133 NW WALL STREET,\nSUITE 105\nBEND, OR, 97703',
#  '1133 NW WALL ST,\nSUITE 105\nBEND, OR, 97703',
#  '4742 LIBERTY ROAD S #182,\n\nSALEM, OR, 97302',
#  '3500 NE 17TH ST,\nAPT G158\nGRESHAM, OR, 97030',
#  '3000 K STREET NW,\nSUITE 330\nWASHINGTON, DC, 20007',
#  '11153 NE WEIDLER ST #C02,\n\nPORTLAND, OR, 97220',
#  '200 W 86TH ST,\nSTE 7M\nNEW YORK, NY, 10024',
#  '11890 SUNRISE VALLEY DRIVE,\nSUITE 206\nRESTON, VA, 20191',
#  '1709 NE 27TH ST,\nSTE A\nMCMINNVILLE, OR, 97128',
#  '620 NE 3RD STREET,\nSUITE A\nMCMINNVILLE, OR, 97128',
#  '295 E MAIN ST #1E,\n\nHERMISTON, OR, 97838',
#  '1700 NE 162ND AVE,\nAPT O4\nPORTLAND, OR, 97230',
#  '511 W BAY STREET,\nSUITE 369\nTAMPA, FL, 33606',
#  '1850 NW FRONT AVE,\nAPT 417\nPORTLAND, OR, 97209',
#  'C/O WENDY LAING,\nPO BOX\nEUGENE, OR, 97440',
#  '1470 NW OVERTON STREET #507,\n\nPORTLAND, OR, 97209',
#  '6228 SW HOOD AVE,\nUPPER UNIT\nPORTLAND, OR, 97239',
#  '25531 COMMERCENTRE DRIVE,\nSUITE 250\nLAKE FOREST, CA, 92630',
#  '2736 MAIN ST,\nAPT 32\nFOREST GROVE, OR, 97116',
#  '2440 S SEPULVEDA BLVD,\nSTE 115\nLOS ANGELES, CA, 90064',
#  '56 SE BRIDGEFORD BLVD,\nSTE 110\nBEND, OR, 97702',
#  '775 SW BONNETT WAY,\nSUITE 220\nBEND, OR, 97702',
#  '250 NW FRANKLIN AVE,\nSTE 101\nBEND, OR, 97703',
#  '2155 NW LABICHE LANE #207,\n\nBEND, OR, 97703',
#  '202 NW JEFFERSON PLACE #1,\n\nBEND, OR, 97703',
#  '1251 E DYER RD,\nSUITE 210\nSANTA ANA, CA, 92705',
#  '#5 4340 KING ST,\n\nDELTA, BRITISH COLUMBIA, V4K 0A5',
#  '5415 NORTH ALBINA AVENUE #318,\n\nPORTLAND, OR, 97217',
#  '5415 NORTH ALBINA AVENUE,\nSUITE 318\nPORTLAND, OR, 97217',
#  '13900 SE HIGHWAY 212,\nUNIT 94\nCLACKAMAS, OR, 97015',
#  '19376 MOLALLA AVE,\nSUITE 150\nOREGON CITY, OR, 97045',
#  '14800 NORTHWEST CORNELL ROAD,\nAPT 12D\nPORTLAND, OR, 97229',
#  '980 HOWE STREET,\nSUITE 201\nVANCOUVER, BRITISH COLUMBIA, V6Z 0C8',
#  '58936 HIGHWAY 19,\nPO BOX 669\nCONDON, OR, 97823',
#  '1760 OLD MEADOW ROAD,\nSUITE 400\nMCLEAN, VA, 22102',
#  '1760 OLD MEADOW ROAD,\nSTE 400\nMCLEAN, VA, 22102',
#  'VANCOUVER WA,\n7403 NE PAR LN\nVANCOUVER, WA, 98662',
#  '2117 NE OREGON ST,\nUNIT 501\nPORTLAND, OR, 97232',
#  '2305 SE WASHINGTON ST,\nSUITE 109\nMILWAUKIE, OR, 97222',
#  '8700 SW BARBUR COURT,\nSUTIE S\nPORTLAND, OR, 97219',
#  '236 N KILLINGSWORTH ST #B304,\n\nPORTLAND, OR, 97217',
#  '335 N 5TH ST,\nPOBOX 1022\nAUMSVILLE, OR, 97325',
#  '915 BROADWAY STREET,\nSUITE 100-112\nVANCOUVER, WA, 98660',
#  'K4,\n311 N ELIZABETH ST\nMILTON FREEWATER, OR, 97862',
#  '311 N ELIZABETH ST,\nK4\nMILTON FREEWATER, OR, 97862',
#  '11918 SE DIVISION ST,\nPMB 128\nPORTLAND, OR, 97266',
#  '30838 9TH PL S,\nB103\nFEDERAL WAY, WA, 98003',
#  '1600 N RIVERSIDE AVE,\nSPACE#2064\nMEDFORD, OR, 97501',
#  '20140 NE SANDY BLV,\nSPACE 5\nFAIRVIEW, OR, 97024',
#  '16869 SW 65TH AVE,\n432\nLAKE OSWEGO, OR, 97035',
#  '15232 NE SANDY BLVD,\nAPT 32\nPORTLAND, OR, 97230',
#  '3439 NE SANDY BLVD,\nSUITE 701\nPORTLAND, OR, 97232',
#  '3439 NE SANDY BLVD,\nSUITE 178\nPORTLAND, OR, 97232',
#  '2020 CENTER ST NE,\nAPT 46\nSALEM, OR, 97301',
#  '30636,\nSW PEACH COVE RD\nWEST LINN, OR, 97068',
#  '17655 SE BLUFF RD #27,\n\nSANDY, OR, 97055',
#  '34505 RIVERSIDE DR SW,\nUNIT 6\nALBANY, OR, 97321',
#  'KENNETH SCHADE,\nPO BOX 187\nMILL CITY, OR, 97360',
#  '390 N 7TH PL,\nGENERAL DELIVERY\nEUGENE, OR, 97440',
#  '3938 NORTH MASSACHUSETTS AVENUE,\nUNIT B\nPORTLAND, OR, 97227',
#  '13640 SE HIGHWAY 212,\nUNITE 86\nCLACKAMAS, OR, 97015',
#  '3773 HOWARD HUGHES PKWY,\nSUITE 500S\nLAS VEGAS, NV, 89169',
#  '3972 BARRANCA PKWY,\nSUITE J-453\nIRVINE, CA, 92606',
#  '1315 NW JOHN FREEMONT ST.,\n\nBEND, OR, 97703',
#  '16110 S. HILLTOP ROAD,\n\nOREGON CITY, OR, 97045',
#  '19550 AMBER MEADOW DRIVE,\n130-2004\nBEND, OR, 97702',
#  '6846 N ROCHESTER ST,\nUNIT B\nPORTLAND, OR, 97203',
#  'PO BOX 409,\nPO BOX 409\nWOODBURN, OR, 97071',
#  '2371 W HAYES ST #59,\n\nWOODBURN, OR, 97071',
#  '17169 MERGANSER DRIVE,\nPO BOX 4321\nBEND, OR, 97707',
#  '7303 NE PRESCOTT ST,\nAPT 1\nPORTLAND, OR, 97218',
#  '138 WEST 25TH STREET,\n5TH FLOOR\nNEW YORK, NY, 10001',
#  'KATHRYN W STONE,\n2829 LAKELAND DR\nFLOWOOD, MS, 39232',
#  '4820 NE HAZEL DELL AVE,\n234\nVANCOUVER, WA, 98663',
#  'THOLANDA NEWBORNE,\n1221 NW 11TH AVE\nPORTLAND, OR, 97209',
#  '9229 QUEENS BLVD,\nSTE 9C\nREGO PARK, NY, 11374',
#  '11530 NE YACHT HARBOR DR,\nD211\nPORTLAND, OR, 97217',
#  '19500 HIDDEN SPRINGS RD,\nB29\nWEST LINN, OR, 97068',
#  '19500 HIDDEN SPRINGS RD,\n29\nWEST LINN, OR, 97068',
#  '410 N MICHIGAN AVENUE,\nSUITE 720\nCHICAGO, IL, 60611',
#  'NW 500 LOST SPRINGS TERRACE,\n104\nPORTLAND, OR, 97229',
#  '775 CASCADE ST #1306,\n\nOREGON CITY, OR, 97045',
#  '13350 OLD KIMBRO ROAD,\nBLDG A\nMANOR, TX, 78653',
#  '130 A AVE #343,\n\nLAKE OSWEGO, OR, 97034',
#  '805 NE KANE DR,\nAPT 109\nGRESHAM, OR, 97030',
#  '13929 FIR STREET,\nSUITE F\nOREGON CITY, OR, 97045',
#  '2397 KINGS BLVD NW #148,\n\nCORVALLIS, OR, 97330',
#  '1515 SE 122ND AVE #1507E,\n\nPORTLAND, OR, 97233',
#  '2373 NW 185TH AVE #158TH,\n\nHILLSBORO, OR, 97124',
#  'PO BOX 280,\n599 4TH ST\nMAUPIN, OR, 97037',
#  '1315 SE 37TH AVE #A,\n\nPORTLAND, OR, 97214',
#  '255 SW HARRISON ST #2D,\n\nPORTLAND, OR, 97201',
#  '1725 NE AINSWORTH STREET,\nLEVEL B\nPORTLAND, OR, 97211',
#  '865 NE TOMAHAWK ISLAND DR,\n102\nPORTLAND, OR, 97217',
#  '1334 MCGEE CT NE,\nAPT 204\nKEIZER, OR, 97303',
#  '235 NE EDISON STREET #D,\n\nHILLSBORO, OR, 97124',
#  '13300 SE 162ND AVE,\n307\nHAPPY VALLEY, OR, 97015',
#  '815 SE 223RD AVE,\nAPT 1\nGRESHAM, OR, 97030',
#  '2505 SE ASH STREET,\nUNIT A\nPORTLAND, OR, 97214',
#  '2260 SE 39TH LOOP,\nSUITE D\nHILLSBORO, OR, 97123',
#  '119 SE 78TH AVE,\nAPT LOWER\nPORTLAND, OR, 97215',
#  '3036 NE 61ST AVE,\nUNIT A\nPORTLAND, OR, 97213',
#  '381 PARK AVENUE SOUTH,\nSUITE 1011\nNEW YORK, NY, 10016',
#  '6025 JEAN ROAD,\nSUITE B\nLAKE OSWEGO, OR, 97035',
#  '1912 4TH ST,\nSTE 400\nLA GRANDE, OR, 97850',
#  '2210 NE 92ND ST #206,\n\nSEATTLE, WA, 98115',
#  '2329 SE KELLER AVE,\nSUITE B\nGRESHAM, OR, 97080',
#  '4925 SW JAMIESON RDA,\nAPT 38\nBEAVERTON, OR, 97005',
#  '1867 WILLIAMS HIGHWAY,\nSUITE 290\nGRANTS PASS, OR, 97527',
#  '700 N BRAND BLVD,\nSUITE 950\nGLENDALE, CA, 91203',
#  '7915 SE KING RD,\nAPT 6\nMILWAUKIE, OR, 97222',
#  '7915 SE KING ST,\nAPT 6\nMILWAUKIE, OR, 97222',
#  'PORTLAND OR,\n4128 SE 64TH AVE\nPORTLAND, OR, 97206',
#  '1721 22ND AVE,\nUNIT A\nFOREST GROVE, OR, 97116',
#  'ANDREW J BEAN,\nPO BOX 667\nALBANY, OR, 97321',
#  '885 NW GRANT AVE,\nSTE A\nCORVALLIS, OR, 97330',
#  '295 E JACKSON,\nPO 493\nCANNON BEACH, OR, 97110',
#  '263 N HEMLOCK,\nSUITE B\nCANNON BEACH, OR, 97110',
#  '254 MARTINE AVE #4C,\n\nWHITE PLAINS, NY, 10601',
#  '2850 NE 65TH AVE,\nSTE B\nVANCOUVER, WA, 98661',
#  '1250 LINDA STREET,\nSUITE 103\nROCKY RIVER, OH, 44116',
#  '1020 SUNCAST LANE #104,\n\nEL DORADO HILLS, CA, 95762',
#  '901 O AVE,\nAPT 1\nLA GRANDE, OR, 97850',
#  '63455 N HIGHWAY 97,\nSTE 32\nBEND, OR, 97703',
#  '63455 N HWY 97,\nSUITE 32\nBEND, OR, 97703',
#  '63455 N HIGHWAY 97,\nSUITE 32\nBEND, OR, 97703',
#  '4741 N MISSISSIPPI,\nPO BOX 11104\nPORTLAND, OR, 97217',
#  '9706 4TH AVE NE,\nSTE 102\nSEATTLE, WA, 98115',
#  'KERBY CARAMBOT,\n3972 CALAROGA DR\nWEST LINN, OR, 97068',
#  '4477 COLBATH AVE #21,\n\nSHERMAN OAKS, CA, 91423',
#  '958 NE KELLY AVE #B,\n\nGRESHAM, OR, 97030',
#  '14825 SW FARMINGTON RD,\nROOM G8A\nBEAVERTON, OR, 97007',
#  '14825 SW FARMINGTON ROAD,\nUNIT G8A\nBEAVERTON, OR, 97007']
