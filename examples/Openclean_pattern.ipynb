# %% [markdown]
# ## Pattern Exercises

# %% [markdown]
# Goals:
# 1. generate patterns
# 2. basic anomalies
# 3. advanced anomalies

# %%
import pandas as pd
import pprint

pp = pprint.PrettyPrinter(indent=4)

# %%
# load data
df = pd.read_csv('../resources/dev/urban.csv')
pp.pprint(df.shape)
df.head()
# Out:
# (31450, 17)
#    Registry Number      Business Name                        Entity Type  \
# 0        167799296   ANOVAWORKS, PLLC  FOREIGN LIMITED LIABILITY COMPANY
# 1        167799296   ANOVAWORKS, PLLC  FOREIGN LIMITED LIABILITY COMPANY
# 2        167799296   ANOVAWORKS, PLLC  FOREIGN LIMITED LIABILITY COMPANY
# 3        168957992  BLACK CROWS CORP.       FOREIGN BUSINESS CORPORATION
# 4        168957992  BLACK CROWS CORP.       FOREIGN BUSINESS CORPORATION
#
#   Registry Date         Associated Name Type First Name Middle Name Last Name  \
# 0    07/01/2020              MAILING ADDRESS        NaN         NaN       NaN
# 1    07/01/2020  PRINCIPAL PLACE OF BUSINESS        NaN         NaN       NaN
# 2    07/01/2020             REGISTERED AGENT        NaN         NaN       NaN
# 3    07/01/2020              MAILING ADDRESS        NaN         NaN       NaN
# 4    07/01/2020                    PRESIDENT       ERIC         NaN    BASCLE
#
#   Suffix Not of Record Entity  Entity of Record Reg Number  \
# 0    NaN                  NaN                          NaN
# 1    NaN                  NaN                          NaN
# 2    NaN                  NaN                   51329093.0
# 3    NaN                  NaN                          NaN
# 4    NaN                  NaN                          NaN
#
#             Entity of Record Name                  Address   \
# 0                             NaN          413 N MISSION ST
# 1                             NaN          413 N MISSION ST
# 2  NORTHWEST REGISTERED AGENT LLC           5305 RIVER RD N
# 3                             NaN  C/O PRAMEX INTERNATIONAL
# 4                             NaN  C/O PRAMEX INTERNATIONAL
#
#                   Address Continued       City State Zip Code
# 0                               NaN  WENATCHEE    WA    98801
# 1                               NaN  WENATCHEE    WA    98801
# 2                             STE B     KEIZER    OR    97303
# 3  1251 AVENUE OF THE AMERICAS, FL3   NEW YORK    NY    10020
# 4  1251 AVENUE OF THE AMERICAS, FL3   NEW YORK    NY    10020

# %% [markdown]
# ### Generate Patterns

# %%
# using the default patternfinder to quickly understand column patterns
from openclean_pattern.patternfinder import PatternFinder
column = 'Entity Type'

# %%
# create a new PatternFinder object with the data series
pf = PatternFinder(
    series = df[column]
)

# %%
# find patterns
patterns = pf.find()

# %%
pp.pprint(patterns)
# Out:
# {   5: PatternRow(ALPHA(7-8) (1-1)ALPHA(7-12) (1-1)ALPHA(4-11)),
#     7: PatternRow(XoXeXXXX(7-8) (1-1)limited(7-7) (1-1)liability(9-9) (1-1)company(7-7)),
#     9: PatternRow(XoXeXXXX(7-8) (1-1)registered(10-10) (1-1)limited(7-7) (1-1)liability(9-9) (1-1)partnership(11-11))}

# %%
# analyze all identified patterns from the column 
for i in range(1,len(patterns)+1):
    pp.pprint("## Pattern Ranked {} for column: {}".format(i, column))
    pp.pprint(pf.top(i))
    pp.pprint(pf.top(i).freq)
    pp.pprint(df.loc[list(pf.top(i).idx), column].unique())
    print()
# Out:
# '## Pattern Ranked 1 for column: Entity Type'
# PatternRow(XoXeXXXX(7-8) (1-1)limited(7-7) (1-1)liability(9-9) (1-1)company(7-7))
# 21020
# array(['FOREIGN LIMITED LIABILITY COMPANY',
#        'DOMESTIC LIMITED LIABILITY COMPANY'], dtype=object)
#
# '## Pattern Ranked 2 for column: Entity Type'
# PatternRow(ALPHA(7-8) (1-1)ALPHA(7-12) (1-1)ALPHA(4-11))
# 10413
# array(['FOREIGN BUSINESS CORPORATION', 'ASSUMED BUSINESS NAME',
#        'DOMESTIC PROFESSIONAL CORPORATION',
#        'DOMESTIC BUSINESS CORPORATION', 'DOMESTIC NONPROFIT CORPORATION',
#        'FOREIGN LIMITED PARTNERSHIP', 'FOREIGN NONPROFIT CORPORATION',
#        'FOREIGN PROFESSIONAL CORPORATION', 'DOMESTIC BUSINESS TRUST',
#        'DOMESTIC LIMITED PARTNERSHIP'], dtype=object)
#
# '## Pattern Ranked 3 for column: Entity Type'
# PatternRow(XoXeXXXX(7-8) (1-1)registered(10-10) (1-1)limited(7-7) (1-1)liability(9-9) (1-1)partnership(11-11))
# 17
# array(['FOREIGN REGISTERED LIMITED LIABILITY PARTNERSHIP',
#        'DOMESTIC REGISTERED LIMITED LIABILITY PARTNERSHIP'], dtype=object)

# %% [markdown]
# ### Basic Outliers

# %%
# create a new PatternFinder object with the data series
column = 'Zip Code'
pf = PatternFinder(
    series = df[column]
)
patterns = pf.find()

# %%
# looking at the patterns discovered in the zipcode column, we see there are 36 values 
# that deviate from the rest of the column 
for i in range(1,len(patterns)+1):
    pp.pprint("## Pattern Ranked {} for column: {}".format(i, column))
    pp.pprint(pf.top(i))
    pp.pprint(pf.top(i).freq)
    pp.pprint(df.loc[list(pf.top(i).idx), column].unique())
    print()
# Out:
# '## Pattern Ranked 1 for column: Zip Code'
# PatternRow(NUMERIC(5-5))
# 31414
# array(['98801', '97303', '10020', ..., '95441', '57702', '27103'],
#       dtype=object)
#
# '## Pattern Ranked 2 for column: Zip Code'
# PatternRow(ALPHANUM(3-3) (1-1)ALPHANUM(3-3))
# 36
# array(['H9R 6B1', 'T6J 7J8', 'M5E 1K3', 'V4K 0A5', 'V6Z 0C8', 'M4M 3G3',
#        'V4N 5K8', 'V5M 4T5', 'V6C 1C7'], dtype=object)

# %%
# they are canadian zipcodes
df.loc[list(pf.top(i).idx)]
# Out:
#        Registry Number                            Business Name  \
# 21377        169759496           NOBLE FOODS NUTRITION USA INC.
# 22915        169824894                       CONNECTION HUB LLC
# 22916        169824894                       CONNECTION HUB LLC
# 12421        169404796                       MKII SERVICE, INC.
# 12422        169404796                       MKII SERVICE, INC.
# 22917        169824894                       CONNECTION HUB LLC
# 12424        169404796                       MKII SERVICE, INC.
# 15631        169469294                  TASMAN AIR SERVICES LLC
# 21399        169765295  NOBLE FOODS NUTRITION USA HOLDINGS INC.
# 21400        169765295  NOBLE FOODS NUTRITION USA HOLDINGS INC.
# 12441        169405199               MK PAYMENT SOLUTIONS, INC.
# 12442        169405199               MK PAYMENT SOLUTIONS, INC.
# 21401        169765295  NOBLE FOODS NUTRITION USA HOLDINGS INC.
# 12444        169405199               MK PAYMENT SOLUTIONS, INC.
# 21403        169765295  NOBLE FOODS NUTRITION USA HOLDINGS INC.
# 12464        169405496                     MKII MARKETING, INC.
# 12465        169405496                     MKII MARKETING, INC.
# 12467        169405496                     MKII MARKETING, INC.
# 16323        169561496                      TPD RESOURCES, INC.
# 16326        169561496                      TPD RESOURCES, INC.
# 16200        169480192                     SLANG WORLDWIDE INC.
# 21210        167724799                DESIGN TRANSPORT USA INC.
# 21211        167724799                DESIGN TRANSPORT USA INC.
# 21212        167724799                DESIGN TRANSPORT USA INC.
# 21213        167724799                DESIGN TRANSPORT USA INC.
# 16351        169564193                 QUARTECH CORRECTIONS LLC
# 16352        169564193                 QUARTECH CORRECTIONS LLC
# 16353        169564193                 QUARTECH CORRECTIONS LLC
# 21216        167724799                DESIGN TRANSPORT USA INC.
# 29934        170103197                        TNG MERCHANDISING
# 29935        170103197                        TNG MERCHANDISING
# 29936        170103197                        TNG MERCHANDISING
# 29937        170103197                        TNG MERCHANDISING
# 21373        169759496           NOBLE FOODS NUTRITION USA INC.
# 21374        169759496           NOBLE FOODS NUTRITION USA INC.
# 21375        169759496           NOBLE FOODS NUTRITION USA INC.
#
#                               Entity Type Registry Date  \
# 21377        FOREIGN BUSINESS CORPORATION    07/22/2020
# 22915  DOMESTIC LIMITED LIABILITY COMPANY    07/24/2020
# 22916  DOMESTIC LIMITED LIABILITY COMPANY    07/24/2020
# 12421        FOREIGN BUSINESS CORPORATION    07/14/2020
# 12422        FOREIGN BUSINESS CORPORATION    07/14/2020
# 22917  DOMESTIC LIMITED LIABILITY COMPANY    07/24/2020
# 12424        FOREIGN BUSINESS CORPORATION    07/14/2020
# 15631  DOMESTIC LIMITED LIABILITY COMPANY    07/16/2020
# 21399        FOREIGN BUSINESS CORPORATION    07/22/2020
# 21400        FOREIGN BUSINESS CORPORATION    07/22/2020
# 12441        FOREIGN BUSINESS CORPORATION    07/14/2020
# 12442        FOREIGN BUSINESS CORPORATION    07/14/2020
# 21401        FOREIGN BUSINESS CORPORATION    07/22/2020
# 12444        FOREIGN BUSINESS CORPORATION    07/14/2020
# 21403        FOREIGN BUSINESS CORPORATION    07/22/2020
# 12464        FOREIGN BUSINESS CORPORATION    07/14/2020
# 12465        FOREIGN BUSINESS CORPORATION    07/14/2020
# 12467        FOREIGN BUSINESS CORPORATION    07/14/2020
# 16323        FOREIGN BUSINESS CORPORATION    07/17/2020
# 16326        FOREIGN BUSINESS CORPORATION    07/17/2020
# 16200        FOREIGN BUSINESS CORPORATION    07/17/2020
# 21210       DOMESTIC BUSINESS CORPORATION    07/22/2020
# 21211       DOMESTIC BUSINESS CORPORATION    07/22/2020
# 21212       DOMESTIC BUSINESS CORPORATION    07/22/2020
# 21213       DOMESTIC BUSINESS CORPORATION    07/22/2020
# 16351   FOREIGN LIMITED LIABILITY COMPANY    07/17/2020
# 16352   FOREIGN LIMITED LIABILITY COMPANY    07/17/2020
# 16353   FOREIGN LIMITED LIABILITY COMPANY    07/17/2020
# 21216       DOMESTIC BUSINESS CORPORATION    07/22/2020
# 29934               ASSUMED BUSINESS NAME    07/30/2020
# 29935               ASSUMED BUSINESS NAME    07/30/2020
# 29936               ASSUMED BUSINESS NAME    07/30/2020
# 29937               ASSUMED BUSINESS NAME    07/30/2020
# 21373        FOREIGN BUSINESS CORPORATION    07/22/2020
# 21374        FOREIGN BUSINESS CORPORATION    07/22/2020
# 21375        FOREIGN BUSINESS CORPORATION    07/22/2020
#
#                    Associated Name Type First Name Middle Name  Last Name  \
# 21377                         SECRETARY    DOMENIC         NaN    MANCINI
# 22915  INDIVIDUAL WITH DIRECT KNOWLEDGE      SAYED       SAEED      AHMAD
# 22916                   MAILING ADDRESS        NaN         NaN        NaN
# 12421                         PRESIDENT      CLIVE         NaN    KINROSS
# 12422       PRINCIPAL PLACE OF BUSINESS        NaN         NaN        NaN
# 22917                           MANAGER      SAYED       SAEED      AHMAD
# 12424                         SECRETARY      CLIVE         NaN    KINROSS
# 15631                           MANAGER       MARK         NaN    KROEKER
# 21399                   MAILING ADDRESS        NaN         NaN        NaN
# 21400                         PRESIDENT    DOMENIC         NaN    MANCINI
# 12441                         PRESIDENT      CLIVE         NaN    KINROSS
# 12442       PRINCIPAL PLACE OF BUSINESS        NaN         NaN        NaN
# 21401       PRINCIPAL PLACE OF BUSINESS        NaN         NaN        NaN
# 12444                         SECRETARY      CLIVE         NaN    KINROSS
# 21403                         SECRETARY    DOMENIC         NaN    MANCINI
# 12464                         PRESIDENT      CLIVE         NaN    KINROSS
# 12465       PRINCIPAL PLACE OF BUSINESS        NaN         NaN        NaN
# 12467                         SECRETARY      CLIVE         NaN    KINROSS
# 16323                         PRESIDENT       PAUL         NaN   TOURNIER
# 16326                         SECRETARY     LESLIE         NaN   MEINGAST
# 16200       PRINCIPAL PLACE OF BUSINESS        NaN         NaN        NaN
# 21210  INDIVIDUAL WITH DIRECT KNOWLEDGE     DALBIR         NaN       KANG
# 21211                   MAILING ADDRESS        NaN         NaN        NaN
# 21212                         PRESIDENT     DALBIR         NaN       KANG
# 21213       PRINCIPAL PLACE OF BUSINESS        NaN         NaN        NaN
# 16351                   MAILING ADDRESS        NaN         NaN        NaN
# 16352                            MEMBER      DAVID         NaN   MARSHALL
# 16353       PRINCIPAL PLACE OF BUSINESS        NaN         NaN        NaN
# 21216                         SECRETARY     DALBIR         NaN       KANG
# 29934         AUTHORIZED REPRESENTATIVE       NICK         NaN  DESMARIAS
# 29935       PRINCIPAL PLACE OF BUSINESS        NaN         NaN        NaN
# 29936                        REGISTRANT        NaN         NaN        NaN
# 29937                        REGISTRANT        NaN         NaN        NaN
# 21373                   MAILING ADDRESS        NaN         NaN        NaN
# 21374                         PRESIDENT    DOMENIC         NaN    MANCINI
# 21375       PRINCIPAL PLACE OF BUSINESS        NaN         NaN        NaN
#
#       Suffix Not of Record Entity  Entity of Record Reg Number  \
# 21377    NaN                  NaN                          NaN
# 22915    NaN                  NaN                          NaN
# 22916    NaN                  NaN                          NaN
# 12421    NaN                  NaN                          NaN
# 12422    NaN                  NaN                          NaN
# 22917    NaN                  NaN                          NaN
# 12424    NaN                  NaN                          NaN
# 15631    NaN                  NaN                          NaN
# 21399    NaN                  NaN                          NaN
# 21400    NaN                  NaN                          NaN
# 12441    NaN                  NaN                          NaN
# 12442    NaN                  NaN                          NaN
# 21401    NaN                  NaN                          NaN
# 12444    NaN                  NaN                          NaN
# 21403    NaN                  NaN                          NaN
# 12464    NaN                  NaN                          NaN
# 12465    NaN                  NaN                          NaN
# 12467    NaN                  NaN                          NaN
# 16323    NaN                  NaN                          NaN
# 16326    NaN                  NaN                          NaN
# 16200    NaN                  NaN                          NaN
# 21210    NaN                  NaN                          NaN
# 21211    NaN                  NaN                          NaN
# 21212    NaN                  NaN                          NaN
# 21213    NaN                  NaN                          NaN
# 16351    NaN                  NaN                          NaN
# 16352    NaN                  NaN                          NaN
# 16353    NaN                  NaN                          NaN
# 21216    NaN                  NaN                          NaN
# 29934    NaN                  NaN                          NaN
# 29935    NaN                  NaN                          NaN
# 29936    NaN                  NaN                   92881193.0
# 29937    NaN                  NaN                   92881193.0
# 21373    NaN                  NaN                          NaN
# 21374    NaN                  NaN                          NaN
# 21375    NaN                  NaN                          NaN
#
#                Entity of Record Name                             Address   \
# 21377                            NaN                          250 AV AVRO
# 22915                            NaN                  418-11511 27 AVE NW
# 22916                            NaN                  418-11511 27 AVE NW
# 12421                            NaN                69 YONGE ST SUITE 600
# 12422                            NaN                69 YONGE ST SUITE 600
# 22917                            NaN                  418-11511 27 AVE NW
# 12424                            NaN                69 YONGE ST SUITE 600
# 15631                            NaN                      #5 4340 KING ST
# 21399                            NaN                          250 AV AVRO
# 21400                            NaN                          250 AV AVRO
# 12441                            NaN                69 YONGE ST SUITE 600
# 12442                            NaN                69 YONGE ST SUITE 600
# 21401                            NaN                          250 AV AVRO
# 12444                            NaN                69 YONGE ST SUITE 600
# 21403                            NaN                          250 AV AVRO
# 12464                            NaN                69 YONGE ST SUITE 600
# 12465                            NaN                69 YONGE ST SUITE 600
# 12467                            NaN                69 YONGE ST SUITE 600
# 16323                            NaN                      980 HOWE STREET
# 16326                            NaN                      980 HOWE STREET
# 16200                            NaN                    50 CARROLL STREET
# 21210                            NaN                      8705 170 STREET
# 21211                            NaN                      8705 170 STREET
# 21212                            NaN                      8705 170 STREET
# 21213                            NaN                      8705 170 STREET
# 16351                            NaN                   2889 12TH AVENUE E
# 16352                            NaN                   2889 12TH AVENUE E
# 16353                            NaN                   2889 12TH AVENUE E
# 21216                            NaN                      8705 170 STREET
# 29934                            NaN  1067 WEST CORDOVA STREET 18TH FLOOR
# 29935                            NaN  1067 WEST CORDOVA STREET 18TH FLOOR
# 29936  SELECT MEDIA SERVICES, L.L.C.  1067 WEST CORDOVA STREET 18TH FLOOR
# 29937       TNG RETAIL SERVICES, LLC  1067 WEST CORDOVA STREET 18TH FLOOR
# 21373                            NaN                          250 AV AVRO
# 21374                            NaN                          250 AV AVRO
# 21375                            NaN                          250 AV AVRO
#
#       Address Continued           City             State Zip Code
# 21377               NaN  POINTE-CLAIRE            QUEBEC  H9R 6B1
# 22915               NaN       EDMONTON           ALBERTA  T6J 7J8
# 22916               NaN       EDMONTON           ALBERTA  T6J 7J8
# 12421               NaN        TORONTO           ONTARIO  M5E 1K3
# 12422               NaN        TORONTO           ONTARIO  M5E 1K3
# 22917               NaN       EDMONTON           ALBERTA  T6J 7J8
# 12424               NaN        TORONTO           ONTARIO  M5E 1K3
# 15631               NaN          DELTA  BRITISH COLUMBIA  V4K 0A5
# 21399               NaN  POINTE-CLAIRE            QUEBEC  H9R 6B1
# 21400               NaN  POINTE-CLAIRE            QUEBEC  H9R 6B1
# 12441               NaN        TORONTO           ONTARIO  M5E 1K3
# 12442               NaN        TORONTO           ONTARIO  M5E 1K3
# 21401               NaN  POINTE-CLAIRE            QUEBEC  H9R 6B1
# 12444               NaN        TORONTO           ONTARIO  M5E 1K3
# 21403               NaN  POINTE-CLAIRE            QUEBEC  H9R 6B1
# 12464               NaN        TORONTO           ONTARIO  M5E 1K3
# 12465               NaN        TORONTO           ONTARIO  M5E 1K3
# 12467               NaN        TORONTO           ONTARIO  M5E 1K3
# 16323         SUITE 201      VANCOUVER  BRITISH COLUMBIA  V6Z 0C8
# 16326         SUITE 201      VANCOUVER  BRITISH COLUMBIA  V6Z 0C8
# 16200               NaN        TORONTO           ONTARIO  M4M 3G3
# 21210               NaN         SURREY  BRITISH COLUMBIA  V4N 5K8
# 21211               NaN         SURREY  BRITISH COLUMBIA  V4N 5K8
# 21212               NaN         SURREY  BRITISH COLUMBIA  V4N 5K8
# 21213               NaN         SURREY  BRITISH COLUMBIA  V4N 5K8
# 16351         SUITE 650      VANCOUVER  BRITISH COLUMBIA  V5M 4T5
# 16352         SUITE 650      VANCOUVER  BRITISH COLUMBIA  V5M 4T5
# 16353         SUITE 650      VANCOUVER  BRITISH COLUMBIA  V5M 4T5
# 21216               NaN         SURREY  BRITISH COLUMBIA  V4N 5K8
# 29934               NaN      VANCOUVER  BRITISH COLUMBIA  V6C 1C7
# 29935               NaN      VANCOUVER  BRITISH COLUMBIA  V6C 1C7
# 29936               NaN      VANCOUVER  BRITISH COLUMBIA  V6C 1C7
# 29937               NaN      VANCOUVER  BRITISH COLUMBIA  V6C 1C7
# 21373               NaN  POINTE-CLAIRE            QUEBEC  H9R 6B1
# 21374               NaN  POINTE-CLAIRE            QUEBEC  H9R 6B1
# 21375               NaN  POINTE-CLAIRE            QUEBEC  H9R 6B1

# %% [markdown]
# ### Non-Basic Outliers

# %%
# Businesses

# %%
from openclean_pattern.tokenize.regex import RegexTokenizer
from openclean_pattern.datatypes.resolver import BusinessEntityResolver, DefaultTypeResolver

# create a new DefaultTypeResolver object (identifies basic types)
# intercepted by a BusinessEntityResolver (identifies company suffixes)
dtr = DefaultTypeResolver(interceptors=BusinessEntityResolver())

# create a new RegexTokenizer that'll tokenize the remaining values not identified by the type resolvers
# on all delimiters except dots(.) because they're abbreviation characters
rt = RegexTokenizer(type_resolver=dtr, abbreviations=True)

# create a new PatternFinder object with the data series and the TypeResolvers to use as part of the Tokenizer
column = 'Business Name'
pf = PatternFinder(
    series = df[column],
    tokenizer = rt
)

# %%
patterns = pf.find()

# %%
#  Ranked # 5 and 9 dont have any business suffixes
for i in range(1, len(patterns)+1):
    pp.pprint("## Pattern Ranked {} for column: {}".format(i, column))
    pp.pprint(pf.top(i))
    pp.pprint(pf.top(i).freq)
    print()
# Out:
# '## Pattern Ranked 1 for column: Business Name'
# PatternRow(ALPHA(1-14) (1-1)ALPHA(1-14) (1-1)BUSINESS(2-25))
# 6037
#
# '## Pattern Ranked 2 for column: Business Name'
# PatternRow(ALPHA(1-12) (1-1)ALPHA(1-13) (1-1)ALPHA(1-14) (1-1)BUSINESS(2-25))
# 4646
#
# '## Pattern Ranked 3 for column: Business Name'
# PatternRow(ALPHA(1-14) (1-1)ALPHA(1-15)PUNC(,!) (1-1)BUSINESS(2-4))
# 2488
#
# '## Pattern Ranked 4 for column: Business Name'
# PatternRow(ALPHA(1-11) (1-1)ALPHA(1-14) (1-1)ALPHA(1-14)PUNC(,) (1-1)BUSINESS(2-9))
# 2034
#
# '## Pattern Ranked 5 for column: Business Name'
# PatternRow(ALPHA(1-13) (1-1)ALPHA(1-14))
# 2027
#
# '## Pattern Ranked 6 for column: Business Name'
# PatternRow(ALPHA(1-11) (1-1)ALPHA(1-14) (1-1)ALPHA(1-12) (1-1)ALPHA(2-14) (1-1)BUSINESS(3-25))
# 1317
#
# '## Pattern Ranked 7 for column: Business Name'
# PatternRow(ALPHA(3-18)PUNC(,) (1-1)BUSINESS(3-4))
# 674
#
# '## Pattern Ranked 8 for column: Business Name'
# PatternRow(ALPHA(1-11) (1-1)ALPHA(1-12) (1-1)ALPHA(1-14) (1-1)ALPHA(2-12)PUNC(,) (1-1)BUSINESS(2-3))
# 565
#
# '## Pattern Ranked 9 for column: Business Name'
# PatternRow(ALPHA(1-21))
# 535
#
# '## Pattern Ranked 10 for column: Business Name'
# PatternRow(ALPHA(1-11) (1-1)ALPHA(1-12) (1-1)ALPHA(1-12) (1-1)ALPHA(1-14) (1-1)ALPHA(2-13) (1-1)BUSINESS(3-25))
# 357
#
# '## Pattern Ranked 11 for column: Business Name'
# PatternRow(ALPHA(1-11) (1-1)ALPHA(2-10) (1-1)ALPHA(1-11) (1-1)ALPHA(2-11) (1-1)ALPHA(1-14)PUNC(!,) (1-1)BUSINESS(2-3))
# 118
#
# '## Pattern Ranked 12 for column: Business Name'
# PatternRow(ALPHA(1-8) (1-1)ALPHA(1-10) (1-1)ALPHA(1-11) (1-1)ALPHA(2-8) (1-1)ALPHA(3-7) (1-1)ALPHA(3-10) (1-1)BUSINESS(3-11))
# 67
#
# '## Pattern Ranked 13 for column: Business Name'
# PatternRow(ALPHA(1-9) (1-1)ALPHA(1-9) (1-1)ALPHA(3-12) (1-1)ALPHA(4-7) (1-1)ALPHA(6-9) (1-1)BUSINESS(8-11)PUNC(,) (1-1)inc(3-3))
# 17
#
# '## Pattern Ranked 14 for column: Business Name'
# PatternRow(ALPHA(5-10) (1-1)ALPHA(3-8)PUNC(,) (1-1)XXc(3-3)PUNC(,) (1-1)a(1-1) (1-1)BUSINESS(11-25) (1-1)of(2-2) (1-1)ALPHA(4-10))
# 14
#
# '## Pattern Ranked 15 for column: Business Name'
# PatternRow(harris(6-6) (1-1)care(4-4) (1-1)adult(5-5) (1-1)foster(6-6) (1-1)care(4-4) (1-1)and(3-3) (1-1)assisted(8-8) (1-1)living(6-6) (1-1)llc(3-3))
# 7
#
# '## Pattern Ranked 16 for column: Business Name'
# PatternRow(affordable(10-10) (1-1)dentures(8-8) (1-1)PUNC(&) (1-1)implants(8-8) (1-1)PUNC(-) (1-1)springfield(11-11) (1-1)iii(3-3)PUNC(,) (1-1)pc(2-2))
# 6
#
# '## Pattern Ranked 17 for column: Business Name'
# PatternRow(operation(9-9) (1-1)back(4-4) (1-1)to(2-2) (1-1)school(6-6) (1-1)PUNC(:) (1-1)one(3-3) (1-1)cause(5-5)PUNC(,) (1-1)many(4-4) (1-1)hands(5-5))
# 5
#
# '## Pattern Ranked 18 for column: Business Name'
# PatternRow(meghans(7-7) (1-1)place(5-5)PUNC(:) (1-1)outpatient(10-10) (1-1)PUNC(()plus(4-4)PUNC()) (1-1)eating(6-6) (1-1)disorder(8-8) (1-1)therapy(7-7)PUNC(,) (1-1)llc(3-3))
# 5
#
# '## Pattern Ranked 19 for column: Business Name'
# PatternRow(sweet(5-5) (1-1)temptations(11-11) (1-1)delectable(10-10) (1-1)desserts(8-8)PUNC(,) (1-1)catering(8-8) (1-1)company(7-7) (1-1)and(3-3) (1-1)creamery(8-8) (1-1)bar(3-3)PUNC(,) (1-1)llc(3-3))
# 4
#
# '## Pattern Ranked 20 for column: Business Name'
# PatternRow(knights(7-7) (1-1)of(2-2) (1-1)columbus(8-8) (1-1)PUNC(-) (1-1)st(2-2) (1-1)rose(4-4) (1-1)of(2-2) (1-1)lima(4-4) (1-1)council(7-7) (1-1)PUNC(#)17536(5-5))
# 4

# %%
# these businesses dont have a suffix in their names, these could be potential errors
df.loc[pf.top(9).idx, column].unique()
# Out:
# array(['SOULPRIMA', 'PROPHECYTHREE', 'THELOTTER', 'PACKWITHMETRAVEL',
#        'OHT', 'OPENART', 'VIDIVY', 'OIRR', 'FIGURE', 'ONYXTELE',
#        'LAWRENCEMORRELL.COM', 'WHIMSY', 'WAKEPORT', 'NOBLEKNOTS.PNW',
#        'SPEAKUPWITHUS.ORG', 'CREECHARTS', 'DABUDEASE', 'OUELLETTE',
#        'LUCIANOFIT', 'BOOPS', 'POPPLE', 'SAGEANDGRAE', 'SHOPHEYDONAE',
#        'VISIONARYDREAMSFILMS', 'MTNSERVICES', 'ROBOSUSHI', 'SINGCOOKIES',
#        'RHOJOS', 'LOCARE', 'LOWD', 'GUSTO', 'GREATNONPROFITS',
#        'TCBADGERSONELOVE', 'SAFEWAY.COM', 'TINE', 'FERNWOOD',
#        'REDCAKERECYCLE', 'LBHC', 'PERFEITO', 'SHAPED', 'SOUNDNSIGHT',
#        'SQUAWKMEET.COM', 'ESERENITIES', 'TRANSTAT', 'SYNCQUILITY',
#        'OKAASAN', 'DIGITIZED', 'FOUNDED', 'TAGIDI', 'DANU',
#        'RECESSIONSAFETYNET.COM', 'MSARTISTRY', 'AAVANTGARDE', 'ALOE.BLUE',
#        'NORTHSIDEFRIED', 'ALLOW', 'FULAMINGO', 'LUXREDUX', 'NURSETAP',
#        'ANNIESCAPES', 'SPADIX', 'SHOPSHAR', 'SURAYA', "ZELDA'S",
#        'YEONDAE', 'MINUTECLINIC', 'EXESTHETICS', 'RHOGFARM', 'EXCENTRIX',
#        'SYNCHRONOSURE', 'HANSENCNC', 'RANCHLANDNW', 'SALCHI', 'HAVENWARE',
#        'LOKAAL', 'BOHOVYBO', 'DMTRANSPORT', 'QOI', 'ALANDRA', 'JRX',
#        'PIXC', 'ZAANS', 'PROREGLAZE', 'TERMINAL', 'MEDIACREST',
#        'LADYLIKE', 'OCCRA', 'BOOST', 'LEMONNADE', 'ETHICALADS',
#        'BUILDABLE', 'COLORCO', 'DCFIT', 'OARISE.ORG', "MOKE'S",
#        'DROPLETSOFSKINCARE', 'B', 'BARELUCENT', 'ABELFAB', 'BINDLE',
#        'FINDMEDICARE', 'AJILLIANLITTLETHINGS', 'RAYCONO', 'SCHAEFERWERKS',
#        'DEFENDA', 'IPSOLUTIONS', 'ECOJAN', 'AGARI', 'BABYLON', 'FLEITES',
#        'SERENDIPITY', 'GAPCON', 'WISHBONE.STORE', 'LEVELED', 'CNSI',
#        'COOPERATIVA', 'KAYSCLOSET', 'LITTLEMISSFIXIT',
#        'FLUFFFURDAYSFURSUITS', 'GTCUP', 'FINISHWORX', 'FENDELLINGSWORTH',
#        'RETAINITNOW.COM', 'BAYANI', 'NOVANAH', 'QUILTCRAFTCROCHET',
#        'NARWHAL', 'CHERRYPIT', 'MACPAINTING', 'BANDLBOUTIQUESHOP',
#        'ARCIT', 'INNERZONE', 'MONJE', 'RVBO', 'CRAFTSMANJOY',
#        'LIVFITFUEL', 'ABCGARDENING', 'GIBS', 'FIREBIRD', 'KEITHCRAFT',
#        'LOFIJAZZSOUL', 'THEITGIRLS', 'GUNKHOLEGOTHIC', 'RAVENPATHHERBAL',
#        'BLOOMSHOOTER', 'RLF', 'SKELETALIA', 'OCFR', 'NUN',
#        'PARSONSHOSTING', 'OVVIPAY', 'MEDIAKAB', 'FELIZ', 'STEMZEBRA',
#        'ARTERRA', 'CLIQ', 'PENDULUM', 'ODYSSY', 'CONNECTW', 'SHROOM',
#        'MEMORTGAGE', 'PEGMAC', 'RAPIDCAB', 'SPERA', 'GOWORLD',
#        'STARBOARD', 'MEMZY', 'TORIDALEBROUX'], dtype=object)

# %%
#  Address

# %%
from openclean_pattern.datatypes.resolver import AddressDesignatorResolver, GeoSpatialResolver

# %%
# create a new DefaultTypeResolver object (identifies basic types)
# intercepted by an Address and Geospatial Resolver (identify addresses and countries)
dtr = DefaultTypeResolver(interceptors=[AddressDesignatorResolver()])

# create a new RegexTokenizer that'll tokenize the remaining values not identified by the type resolvers
# on all delimiters
rt = RegexTokenizer(type_resolver=dtr)

# create a new PatternFinder object with the data series and the TypeResolvers to use as part of the Tokenizer
column = 'Address '
pf = PatternFinder(
    series = df[column],
    tokenizer = rt
)

# %%
patterns = pf.find()

# %%
# address patterns ranked 10+ seem like possible outliers
for i in range(1, len(patterns)+1):
    pp.pprint("## Pattern Ranked {} for column: {}".format(i, column))
    pp.pprint(pf.top(i))
    pp.pprint(pf.top(i).freq)
    print()
# Out:
# '## Pattern Ranked 1 for column: Address '
# PatternRow(NUMERIC(1-6) (1-1)ALPHA(1-12) (1-1)ALPHA(1-13) (1-1)STREET(2-9))
# 8353
#
# '## Pattern Ranked 2 for column: Address '
# PatternRow(NUMERIC(1-6) (1-1)ALPHA(1-14) (1-1)STREET(2-9))
# 5400
#
# '## Pattern Ranked 3 for column: Address '
# PatternRow(NUMERIC(1-5) (1-1)ALPHA(1-10) (1-1)ALPHA(2-12) (1-1)STREET(2-9) (1-1)SUD(3-5) (1-1)NUMERIC(1-5))
# 1474
#
# '## Pattern Ranked 4 for column: Address '
# PatternRow(NUMERIC(3-5) (1-1)ALPHA(1-9) (1-1)ALPHA(1-10) (1-1)STREET(3-8) (1-1)STREET(2-7))
# 682
#
# '## Pattern Ranked 5 for column: Address '
# PatternRow(NUMERIC(2-5) (1-1)ALPHA(1-5) (1-1)ALPHA(1-10) (1-1)STREET(2-6) (1-1)PUNC(#)NUMERIC(1-5))
# 155
#
# '## Pattern Ranked 6 for column: Address '
# PatternRow(NUMERIC(1-5) (1-1)ALPHA(5-14))
# 81
#
# '## Pattern Ranked 7 for column: Address '
# PatternRow(NUMERIC(3-5) (1-1)ALPHA(1-11) (1-1)STREET(2-7) (1-1)PUNC(#)NUMERIC(1-4))
# 80
#
# '## Pattern Ranked 8 for column: Address '
# PatternRow(NUMERIC(3-5) (1-1)ALPHA(1-2) (1-1)ALPHA(3-10) (1-1)STREET(3-7) (1-1)STREET(2-5) (1-1)SUD(3-5) (1-1)NUMERIC(1-3))
# 59
#
# '## Pattern Ranked 9 for column: Address '
# PatternRow(NUMERIC(3-5) (1-1)ALPHA(2-4) (1-1)ALPHA(4-8) (1-1)STREET(4-6) (1-1)STREET(2-5) (1-1)PUNC(#)NUMERIC(1-4))
# 22
#
# '## Pattern Ranked 10 for column: Address '
# PatternRow(NUMERIC(2-5))
# 14
#
# '## Pattern Ranked 11 for column: Address '
# PatternRow(PUNC(%) (1-1)ipm(3-3) (1-1)1800(4-4) (1-1)sw(2-2) (1-1)1st(3-3) (1-1)ave(3-3) (1-1)ste(3-3) (1-1)2X0(3-3))
# 7
#
# '## Pattern Ranked 12 for column: Address '
# PatternRow(PUNC(#)NUMERIC(1-3))
# 6
#
# '## Pattern Ranked 13 for column: Address '
# PatternRow(2738(4-4) (1-1)se(2-2) (1-1)82nd(4-4) (1-1)ave(3-3) (1-1)apt(3-3) (1-1)101(3-3) (1-1)PUNC(#)201a(4-4))
# 5
#
# '## Pattern Ranked 14 for column: Address '
# PatternRow(185th(5-5) (1-1)ave(3-3) (1-1)PUNC(#)158(3-3))
# 4
#
# '## Pattern Ranked 15 for column: Address '
# PatternRow(5305(4-4) (1-1)river(5-5) (1-1)rd(2-2) (1-1)n(1-1) (1-1)ste(3-3) (1-1)b(1-1) (1-1)keizer(6-6) (1-1)or(2-2) (1-1)97303(5-5))
# 3
#
# '## Pattern Ranked 16 for column: Address '
# PatternRow(13023(5-5) (1-1)ne(2-2) (1-1)hwy(3-3) (1-1)99(2-2) (1-1)ste(3-3) (1-1)7(1-1) (1-1)pmb(3-3) (1-1)PUNC(#)248(3-3))
# 1

# %%
for i in range(10,16):
    pp.pprint(df.loc[pf.top(i).idx, column].unique())
# Out:
# array(['57333', '41', '3518', '30636', '16101'], dtype=object)
# array(['% IPM 1800 SW 1ST AVE STE 220', '% IPM 1800 SW 1ST AVE STE 200'],
#       dtype=object)
# array(['#2', '#162', '#7', '#226'], dtype=object)
# array(['2738 SE 82ND AVE APT 101 #201A'], dtype=object)
# array(['185TH AVE #158'], dtype=object)
# array(['5305 RIVER RD N STE B KEIZER OR 97303'], dtype=object)

# %%
# Geospatial

# %%
# Combined Geo
geo = df[['Address ', 'Address Continued' ,'City' ,'State', 'Zip Code']]
geo.loc[:, 'combined'] = df['City'] + ' ' + df['Zip Code']
# Out:
# /home/maqzi/PycharmProjects/openclean-pattern/venv/lib/python3.7/site-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/maqzi/PycharmProjects/openclean-pattern/venv/lib/python3.7/site-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
geo['combined']
# Out:
# 0          WENATCHEE 98801
# 1          WENATCHEE 98801
# 2             KEIZER 97303
# 3           NEW YORK 10020
# 4           NEW YORK 10020
#                ...
# 31445    OREGON CITY 97045
# 31446    OREGON CITY 97045
# 31447    OREGON CITY 97045
# 31448    OREGON CITY 97045
# 31449    OREGON CITY 97045
# Name: combined, Length: 31450, dtype: object

# %%
# create a new DefaultTypeResolver object (identifies basic types)
# intercepted by an Address and Geospatial Resolver (identify addresses and countries)
dtr = DefaultTypeResolver(interceptors=[GeoSpatialResolver(levels=[])])

# create a new RegexTokenizer that'll tokenize the remaining values not identified by the type resolvers
# on all delimiters
rt = RegexTokenizer(type_resolver=dtr)

# create a new PatternFinder object with the data series and the TypeResolvers to use as part of the Tokenizer
column = 'combined'
pf = PatternFinder(
    series = geo[column],
    tokenizer = rt
)

# %%
pf.find()
# Out:
# {3: PatternRow(ALPHA(3-13) (1-1)NUMERIC(5-5)),
#  5: PatternRow(ALPHA(2-9) (1-1)STREET(3-8) (1-1)NUMERIC(5-5)),
#  7: PatternRow(salt(4-4) (1-1)lake(4-4) (1-1)city(4-4) (1-1)841XX(5-5))}
